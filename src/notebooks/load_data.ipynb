# %%
# %load_ext autoreload
# %autoreload 2

from src.utils.tsp_loader import load_tsp_matrix

dist_matrix = load_tsp_matrix("Dane_TSP_48.xlsx")

print("Macierz odległości:")
print(dist_matrix.shape)
print(dist_matrix[:5, :5])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Macierz odległości:
# (48, 48)
# [[   0. 1495.  381. 2012. 1157.]
#  [1495.    0. 1135.  637.  583.]
#  [ 381. 1135.    0. 1633.  778.]
#  [2012.  637. 1633.    0.  886.]
#  [1157.  583.  778.  886.    0.]]
