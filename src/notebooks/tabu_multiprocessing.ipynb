# %%
# SKRYPT EKSPERYMENTALNY
# Uruchamia analizę algorytmu Tabu Search (TS) dla różnych
# konfiguracji parametrów. Dla każdej kombinacji wykonywane jest
# kilka powtórzeń, zapisywane są statystyki jakości oraz czas
# działania. Wyniki trafiają do pliku CSV.

# %load_ext autoreload
# %autoreload 2

import time
import pandas as pd
import numpy as np
import itertools
from multiprocessing import Pool, cpu_count

from src.utils.tsp_loader import load_tsp_matrix
# from src.algorithms.tabu_move import solve_tsp
from src.algorithms.tabu_full_path import solve_tsp
from src.utils.result_saver import save_experiment_results
from src.utils.run_single_repeat import run_single_repeat


# USTAWIENIA
TSP_FILES = ["Dane_TSP_48.xlsx", "Dane_TSP_76.xlsx", "Dane_TSP_127.xlsx"]

PARAM_GRID = {
    "max_iter": [10_000, 25_000, 75_000, 200_000],
    "stop_no_improve": [1_000, 2_000, 5_000, 7_000],
    "tabu_tenure": [10, 15, 25, 50],
    "n_neighbors": [30, 60, 100, 150],
    "neighborhood_type": ["swap", "insert", "two_opt"],
}

REPEATS = 5
results = []


# ROZGRZANIE (KOMPILACJA JIT JEŚLI WYSTĘPUJE)
print("Rozgrzewanie (kompilacja JIT jeśli dotyczy)...")
D = load_tsp_matrix(TSP_FILES[0])
_ = solve_tsp(D, {"max_iter": 5, "tabu_tenure": 3, "n_neighbors": 5})
print("Kompilacja zakończona.\n")


# GŁÓWNA PĘTLA
# Obliczamy łączną liczbę kombinacji
all_combos = list(itertools.product(
    PARAM_GRID["max_iter"],
    PARAM_GRID["stop_no_improve"],
    PARAM_GRID["tabu_tenure"],
    PARAM_GRID["n_neighbors"],
    PARAM_GRID["neighborhood_type"],
))
total = len(all_combos) * len(TSP_FILES)
counter = 0
start_total = time.perf_counter()

for tsp_file in TSP_FILES:
    print(f"\nInstancja: {tsp_file}")
    D = load_tsp_matrix(tsp_file)

    for max_iter in PARAM_GRID["max_iter"]:
        for stop_no_improve in PARAM_GRID["stop_no_improve"]:
            for tabu_tenure in PARAM_GRID["tabu_tenure"]:
                for n_neighbors in PARAM_GRID["n_neighbors"]:
                    for neighborhood_type in PARAM_GRID["neighborhood_type"]:
                        counter += 1

                        print(
                            f"[{counter}/{total}] "
                            f"max_iter={max_iter}, "
                            f"stop_no_improve={stop_no_improve}, "
                            f"tabu_tenure={tabu_tenure}, "
                            f"n_neighbors={n_neighbors}, "
                            f"neighborhood_type={neighborhood_type}"
                        )

                        params = {
                            "max_iter": max_iter,
                            "stop_no_improve": stop_no_improve,
                            "tabu_tenure": tabu_tenure,
                            "n_neighbors": n_neighbors,
                            "neighborhood_type": neighborhood_type,
                        }

                        # multiprocessing — równoległe powtórzenia
                        with Pool(processes=cpu_count()) as pool:
                            parallel_jobs = [
                                (solve_tsp, D, params) for _ in range(REPEATS)
                            ]
                            results_parallel = pool.map(run_single_repeat, parallel_jobs)

                        # --- ZBIERANIE DANYCH ---
                        costs = [c for c, _, _ in results_parallel]
                        routes = [r for _, r, _ in results_parallel]
                        runtimes = [t for _, _, t in results_parallel]

                        # najlepsza trasa
                        min_cost = min(costs)
                        best_route_overall = routes[costs.index(min_cost)]
                        route_str = "-".join(map(str, best_route_overall))

                        results.append({
                            "instance": tsp_file,
                            "max_iter": max_iter,
                            "stop_no_improve": stop_no_improve,
                            "tabu_tenure": tabu_tenure,
                            "n_neighbors": n_neighbors,
                            "neighborhood_type": neighborhood_type,
                            "mean_cost": round(np.mean(costs), 3),
                            "mean_runtime": np.mean(runtimes),
                            "min_cost": round(min_cost, 3),
                            "min_route": route_str,
                        })

# ZAPIS WYNIKÓW
end_total = time.perf_counter()
elapsed = end_total - start_total

df = pd.DataFrame(results)
save_experiment_results(df, filename='tabu_move_results.csv', time_seconds=int(elapsed), subfolder="TS")


# RAPORT
print(f"\nŁączny czas eksperymentów: {elapsed/60:.2f} min ({elapsed:.2f} sek)")

print("\nNajlepsze parametry dla każdej instancji:")

instances = df["instance"].unique()

for inst in instances:
    sub = df[df["instance"] == inst]
    best_row = sub.loc[sub["mean_cost"].idxmin()]
    print(f"\n{inst}")
    # print(best_row["min_cost"], best_row.to_dict())
    print(f"odległość {best_row["min_cost"]} = {best_row.to_dict()}")
# Out:
# Rozgrzewanie (kompilacja JIT jeśli dotyczy)...
# Kompilacja zakończona.
#
#
# Instancja: Dane_TSP_48.xlsx
# [1/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=10, n_neighbors=30, neighborhood_type=swap
# [2/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=10, n_neighbors=30, neighborhood_type=insert
# [3/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=10, n_neighbors=30, neighborhood_type=two_opt
# [4/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=10, n_neighbors=60, neighborhood_type=swap
# [5/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=10, n_neighbors=60, neighborhood_type=insert
# [6/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=10, n_neighbors=60, neighborhood_type=two_opt
# [7/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=10, n_neighbors=100, neighborhood_type=swap
# [8/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=10, n_neighbors=100, neighborhood_type=insert
# [9/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=10, n_neighbors=100, neighborhood_type=two_opt
# [10/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=10, n_neighbors=150, neighborhood_type=swap
# [11/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=10, n_neighbors=150, neighborhood_type=insert
# [12/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=10, n_neighbors=150, neighborhood_type=two_opt
# [13/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=15, n_neighbors=30, neighborhood_type=swap
# [14/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=15, n_neighbors=30, neighborhood_type=insert
# [15/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=15, n_neighbors=30, neighborhood_type=two_opt
# [16/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=15, n_neighbors=60, neighborhood_type=swap
# [17/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=15, n_neighbors=60, neighborhood_type=insert
# [18/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=15, n_neighbors=60, neighborhood_type=two_opt
# [19/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=15, n_neighbors=100, neighborhood_type=swap
# [20/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=15, n_neighbors=100, neighborhood_type=insert
# [21/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=15, n_neighbors=100, neighborhood_type=two_opt
# [22/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=15, n_neighbors=150, neighborhood_type=swap
# [23/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=15, n_neighbors=150, neighborhood_type=insert
# [24/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=15, n_neighbors=150, neighborhood_type=two_opt
# [25/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=25, n_neighbors=30, neighborhood_type=swap
# [26/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=25, n_neighbors=30, neighborhood_type=insert
# [27/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=25, n_neighbors=30, neighborhood_type=two_opt
# [28/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=25, n_neighbors=60, neighborhood_type=swap
# [29/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=25, n_neighbors=60, neighborhood_type=insert
# [30/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=25, n_neighbors=60, neighborhood_type=two_opt
# [31/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=25, n_neighbors=100, neighborhood_type=swap
# [32/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=25, n_neighbors=100, neighborhood_type=insert
# [33/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=25, n_neighbors=100, neighborhood_type=two_opt
# [34/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=25, n_neighbors=150, neighborhood_type=swap
# [35/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=25, n_neighbors=150, neighborhood_type=insert
# [36/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=25, n_neighbors=150, neighborhood_type=two_opt
# [37/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=50, n_neighbors=30, neighborhood_type=swap
# [38/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=50, n_neighbors=30, neighborhood_type=insert
# [39/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=50, n_neighbors=30, neighborhood_type=two_opt
# [40/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=50, n_neighbors=60, neighborhood_type=swap
# [41/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=50, n_neighbors=60, neighborhood_type=insert
# [42/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=50, n_neighbors=60, neighborhood_type=two_opt
# [43/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=50, n_neighbors=100, neighborhood_type=swap
# [44/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=50, n_neighbors=100, neighborhood_type=insert
# [45/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=50, n_neighbors=100, neighborhood_type=two_opt
# [46/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=50, n_neighbors=150, neighborhood_type=swap
# [47/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=50, n_neighbors=150, neighborhood_type=insert
# [48/2304] max_iter=10000, stop_no_improve=1000, tabu_tenure=50, n_neighbors=150, neighborhood_type=two_opt
# [49/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=10, n_neighbors=30, neighborhood_type=swap
# [50/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=10, n_neighbors=30, neighborhood_type=insert
# [51/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=10, n_neighbors=30, neighborhood_type=two_opt
# [52/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=10, n_neighbors=60, neighborhood_type=swap
# [53/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=10, n_neighbors=60, neighborhood_type=insert
# [54/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=10, n_neighbors=60, neighborhood_type=two_opt
# [55/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=10, n_neighbors=100, neighborhood_type=swap
# [56/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=10, n_neighbors=100, neighborhood_type=insert
# [57/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=10, n_neighbors=100, neighborhood_type=two_opt
# [58/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=10, n_neighbors=150, neighborhood_type=swap
# [59/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=10, n_neighbors=150, neighborhood_type=insert
# [60/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=10, n_neighbors=150, neighborhood_type=two_opt
# [61/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=15, n_neighbors=30, neighborhood_type=swap
# [62/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=15, n_neighbors=30, neighborhood_type=insert
# [63/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=15, n_neighbors=30, neighborhood_type=two_opt
# [64/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=15, n_neighbors=60, neighborhood_type=swap
# [65/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=15, n_neighbors=60, neighborhood_type=insert
# [66/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=15, n_neighbors=60, neighborhood_type=two_opt
# [67/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=15, n_neighbors=100, neighborhood_type=swap
# [68/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=15, n_neighbors=100, neighborhood_type=insert
# [69/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=15, n_neighbors=100, neighborhood_type=two_opt
# [70/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=15, n_neighbors=150, neighborhood_type=swap
# [71/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=15, n_neighbors=150, neighborhood_type=insert
# [72/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=15, n_neighbors=150, neighborhood_type=two_opt
# [73/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=25, n_neighbors=30, neighborhood_type=swap
# [74/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=25, n_neighbors=30, neighborhood_type=insert
# [75/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=25, n_neighbors=30, neighborhood_type=two_opt
# [76/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=25, n_neighbors=60, neighborhood_type=swap
# [77/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=25, n_neighbors=60, neighborhood_type=insert
# [78/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=25, n_neighbors=60, neighborhood_type=two_opt
# [79/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=25, n_neighbors=100, neighborhood_type=swap
# [80/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=25, n_neighbors=100, neighborhood_type=insert
# [81/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=25, n_neighbors=100, neighborhood_type=two_opt
# [82/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=25, n_neighbors=150, neighborhood_type=swap
# [83/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=25, n_neighbors=150, neighborhood_type=insert
# [84/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=25, n_neighbors=150, neighborhood_type=two_opt
# [85/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=50, n_neighbors=30, neighborhood_type=swap
# [86/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=50, n_neighbors=30, neighborhood_type=insert
# [87/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=50, n_neighbors=30, neighborhood_type=two_opt
# [88/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=50, n_neighbors=60, neighborhood_type=swap
# [89/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=50, n_neighbors=60, neighborhood_type=insert
# [90/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=50, n_neighbors=60, neighborhood_type=two_opt
# [91/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=50, n_neighbors=100, neighborhood_type=swap
# [92/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=50, n_neighbors=100, neighborhood_type=insert
# [93/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=50, n_neighbors=100, neighborhood_type=two_opt
# [94/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=50, n_neighbors=150, neighborhood_type=swap
# [95/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=50, n_neighbors=150, neighborhood_type=insert
# [96/2304] max_iter=10000, stop_no_improve=2000, tabu_tenure=50, n_neighbors=150, neighborhood_type=two_opt
# [97/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=10, n_neighbors=30, neighborhood_type=swap
# [98/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=10, n_neighbors=30, neighborhood_type=insert
# [99/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=10, n_neighbors=30, neighborhood_type=two_opt
# [100/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=10, n_neighbors=60, neighborhood_type=swap
# [101/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=10, n_neighbors=60, neighborhood_type=insert
# [102/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=10, n_neighbors=60, neighborhood_type=two_opt
# [103/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=10, n_neighbors=100, neighborhood_type=swap
# [104/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=10, n_neighbors=100, neighborhood_type=insert
# [105/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=10, n_neighbors=100, neighborhood_type=two_opt
# [106/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=10, n_neighbors=150, neighborhood_type=swap
# [107/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=10, n_neighbors=150, neighborhood_type=insert
# [108/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=10, n_neighbors=150, neighborhood_type=two_opt
# [109/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=15, n_neighbors=30, neighborhood_type=swap
# [110/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=15, n_neighbors=30, neighborhood_type=insert
# [111/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=15, n_neighbors=30, neighborhood_type=two_opt
# [112/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=15, n_neighbors=60, neighborhood_type=swap
# [113/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=15, n_neighbors=60, neighborhood_type=insert
# [114/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=15, n_neighbors=60, neighborhood_type=two_opt
# [115/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=15, n_neighbors=100, neighborhood_type=swap
# [116/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=15, n_neighbors=100, neighborhood_type=insert
# [117/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=15, n_neighbors=100, neighborhood_type=two_opt
# [118/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=15, n_neighbors=150, neighborhood_type=swap
# [119/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=15, n_neighbors=150, neighborhood_type=insert
# [120/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=15, n_neighbors=150, neighborhood_type=two_opt
# [121/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=25, n_neighbors=30, neighborhood_type=swap
# [122/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=25, n_neighbors=30, neighborhood_type=insert
# [123/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=25, n_neighbors=30, neighborhood_type=two_opt
# [124/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=25, n_neighbors=60, neighborhood_type=swap
# [125/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=25, n_neighbors=60, neighborhood_type=insert
# [126/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=25, n_neighbors=60, neighborhood_type=two_opt
# [127/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=25, n_neighbors=100, neighborhood_type=swap
# [128/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=25, n_neighbors=100, neighborhood_type=insert
# [129/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=25, n_neighbors=100, neighborhood_type=two_opt
# [130/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=25, n_neighbors=150, neighborhood_type=swap
# [131/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=25, n_neighbors=150, neighborhood_type=insert
# [132/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=25, n_neighbors=150, neighborhood_type=two_opt
# [133/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=50, n_neighbors=30, neighborhood_type=swap
# [134/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=50, n_neighbors=30, neighborhood_type=insert
# [135/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=50, n_neighbors=30, neighborhood_type=two_opt
# [136/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=50, n_neighbors=60, neighborhood_type=swap
# [137/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=50, n_neighbors=60, neighborhood_type=insert
# [138/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=50, n_neighbors=60, neighborhood_type=two_opt
# [139/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=50, n_neighbors=100, neighborhood_type=swap
# [140/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=50, n_neighbors=100, neighborhood_type=insert
# [141/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=50, n_neighbors=100, neighborhood_type=two_opt
# [142/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=50, n_neighbors=150, neighborhood_type=swap
# [143/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=50, n_neighbors=150, neighborhood_type=insert
# [144/2304] max_iter=10000, stop_no_improve=5000, tabu_tenure=50, n_neighbors=150, neighborhood_type=two_opt
# [145/2304] max_iter=10000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=30, neighborhood_type=swap
# [146/2304] max_iter=10000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=30, neighborhood_type=insert
# [147/2304] max_iter=10000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=30, neighborhood_type=two_opt
# [148/2304] max_iter=10000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=60, neighborhood_type=swap
# [149/2304] max_iter=10000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=60, neighborhood_type=insert
# [150/2304] max_iter=10000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=60, neighborhood_type=two_opt
# [151/2304] max_iter=10000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=100, neighborhood_type=swap
# [152/2304] max_iter=10000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=100, neighborhood_type=insert
# [153/2304] max_iter=10000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=100, neighborhood_type=two_opt
# [154/2304] max_iter=10000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=150, neighborhood_type=swap
# [155/2304] max_iter=10000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=150, neighborhood_type=insert
# [156/2304] max_iter=10000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=150, neighborhood_type=two_opt
# [157/2304] max_iter=10000, stop_no_improve=7000, tabu_tenure=15, n_neighbors=30, neighborhood_type=swap
# [158/2304] max_iter=10000, stop_no_improve=7000, tabu_tenure=15, n_neighbors=30, neighborhood_type=insert
# [159/2304] max_iter=10000, stop_no_improve=7000, tabu_tenure=15, n_neighbors=30, neighborhood_type=two_opt
# [160/2304] max_iter=10000, stop_no_improve=7000, tabu_tenure=15, n_neighbors=60, neighborhood_type=swap
# [161/2304] max_iter=10000, stop_no_improve=7000, tabu_tenure=15, n_neighbors=60, neighborhood_type=insert
#
2304] max_iter=200000, stop_no_improve=5000, tabu_tenure=50, n_neighbors=150, neighborhood_type=swap
# [2255/2304] max_iter=200000, stop_no_improve=5000, tabu_tenure=50, n_neighbors=150, neighborhood_type=insert
# [2256/2304] max_iter=200000, stop_no_improve=5000, tabu_tenure=50, n_neighbors=150, neighborhood_type=two_opt
# [2257/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=30, neighborhood_type=swap
# [2258/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=30, neighborhood_type=insert
# [2259/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=30, neighborhood_type=two_opt
# [2260/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=60, neighborhood_type=swap
# [2261/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=60, neighborhood_type=insert
# [2262/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=60, neighborhood_type=two_opt
# [2263/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=100, neighborhood_type=swap
# [2264/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=100, neighborhood_type=insert
# [2265/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=100, neighborhood_type=two_opt
# [2266/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=150, neighborhood_type=swap
# [2267/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=150, neighborhood_type=insert
# [2268/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=10, n_neighbors=150, neighborhood_type=two_opt
# [2269/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=15, n_neighbors=30, neighborhood_type=swap
# [2270/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=15, n_neighbors=30, neighborhood_type=insert
# [2271/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=15, n_neighbors=30, neighborhood_type=two_opt
# [2272/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=15, n_neighbors=60, neighborhood_type=swap
# [2273/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=15, n_neighbors=60, neighborhood_type=insert
# [2274/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=15, n_neighbors=60, neighborhood_type=two_opt
# [2275/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=15, n_neighbors=100, neighborhood_type=swap
# [2276/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=15, n_neighbors=100, neighborhood_type=insert
# [2277/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=15, n_neighbors=100, neighborhood_type=two_opt
# [2278/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=15, n_neighbors=150, neighborhood_type=swap
# [2279/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=15, n_neighbors=150, neighborhood_type=insert
# [2280/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=15, n_neighbors=150, neighborhood_type=two_opt
# [2281/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=25, n_neighbors=30, neighborhood_type=swap
# [2282/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=25, n_neighbors=30, neighborhood_type=insert
# [2283/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=25, n_neighbors=30, neighborhood_type=two_opt
# [2284/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=25, n_neighbors=60, neighborhood_type=swap
# [2285/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=25, n_neighbors=60, neighborhood_type=insert
# [2286/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=25, n_neighbors=60, neighborhood_type=two_opt
# [2287/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=25, n_neighbors=100, neighborhood_type=swap
# [2288/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=25, n_neighbors=100, neighborhood_type=insert
# [2289/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=25, n_neighbors=100, neighborhood_type=two_opt
# [2290/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=25, n_neighbors=150, neighborhood_type=swap
# [2291/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=25, n_neighbors=150, neighborhood_type=insert
# [2292/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=25, n_neighbors=150, neighborhood_type=two_opt
# [2293/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=50, n_neighbors=30, neighborhood_type=swap
# [2294/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=50, n_neighbors=30, neighborhood_type=insert
# [2295/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=50, n_neighbors=30, neighborhood_type=two_opt
# [2296/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=50, n_neighbors=60, neighborhood_type=swap
# [2297/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=50, n_neighbors=60, neighborhood_type=insert
# [2298/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=50, n_neighbors=60, neighborhood_type=two_opt
# [2299/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=50, n_neighbors=100, neighborhood_type=swap
# [2300/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=50, n_neighbors=100, neighborhood_type=insert
# [2301/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=50, n_neighbors=100, neighborhood_type=two_opt
# [2302/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=50, n_neighbors=150, neighborhood_type=swap
# [2303/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=50, n_neighbors=150, neighborhood_type=insert
# [2304/2304] max_iter=200000, stop_no_improve=7000, tabu_tenure=50, n_neighbors=150, neighborhood_type=two_opt
#
# Podsumowanie (pierwsze 20 wierszy):
#         instance  max_iter  stop_no_improve  tabu_tenure  n_neighbors neighborhood_type  mean_cost  mean_runtime  min_cost                                                                                                                             min_route
# Dane_TSP_48.xlsx    200000             7000           25          100           two_opt    10676.8     12.492461   10628.0 37-7-0-8-39-14-11-10-12-24-13-22-2-21-15-40-33-28-1-25-3-34-44-9-23-41-4-47-38-31-20-46-19-32-45-35-29-42-16-26-18-36-5-27-6-17-43-30
# Dane_TSP_48.xlsx     75000             7000           25          150           two_opt    10644.2     19.221968   10628.0 13-24-12-10-11-14-39-8-0-7-37-30-43-17-6-27-5-36-18-26-16-42-29-35-45-32-19-46-20-31-38-47-4-41-23-9-44-34-3-25-1-28-33-40-15-21-2-22
# Dane_TSP_48.xlsx     10000             7000           15          100            insert    10970.4      9.180294   10628.0 10-11-14-39-8-0-7-37-30-43-17-6-27-5-36-18-26-16-42-29-35-45-32-19-46-20-31-38-47-4-41-23-9-