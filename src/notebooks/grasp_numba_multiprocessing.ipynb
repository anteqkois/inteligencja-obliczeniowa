# %%
# GRASP – SKRYPT EKSPERYMENTALNY
# Uruchamia serię eksperymentów dla algorytmu GRASP z różnymi
# parametrami. Struktura analogiczna do IHC, TS, SA itd.
#
# Wymagane:
#   - solve_tsp() z grasp_numba
#   - run_single_repeat()
#   - save_experiment_results()
#   - load_tsp_matrix()

# %load_ext autoreload
# %autoreload 2

import time
import pandas as pd
import numpy as np
import itertools
from multiprocessing import Pool, cpu_count

from src.utils.tsp_loader import load_tsp_matrix
from src.algorithms.grasp_numba import solve_tsp
from src.utils.run_single_repeat import run_single_repeat
from src.utils.result_saver import save_experiment_results


# USTAWIENIA EKSPERYMENTU

TSP_FILES = ["Dane_TSP_48.xlsx", "Dane_TSP_76.xlsx", "Dane_TSP_127.xlsx"]
# TSP_FILES = ["Dane_TSP_48.xlsx"]

PARAM_GRID_GRASP = {
    "alpha": [0.2, 0.4, 0.6, 0.8],
    "iterations": [3_000, 5_000, 8_000, 10_000],
    "neighborhood_type": ["swap", "insert", "two_opt"],
    # parametry local-search (IHC-light)
    "ihc_max_iter": [4_000, 6_000, 8_000],
    "ihc_stop_no_improve": [400, 800, 1_500],
    # "use_delta": [True], # zawsze delta
    "use_delta": [False], # bez delta
}

REPEATS = 5
results = []


# ROZGRZANIE

print("Rozgrzewanie Numba (kompilacja GRASP + IHC-light)...")

D_tmp = load_tsp_matrix(TSP_FILES[0])

# poprawna rozgrzewka: solve_tsp wymaga neighborhood_type jako string
_ = solve_tsp(D_tmp, {
    "alpha": 0.3,
    "iterations": 2,
    "neighborhood_type": "swap",
    "ihc_max_iter": 50,
    "ihc_stop_no_improve": 10,
    "use_delta": False,
})

print("Rozgrzewanie zakończone.\n")


# LISTA KOMBINACJI PARAMETRÓW

all_combos = list(itertools.product(
    PARAM_GRID_GRASP["alpha"],
    PARAM_GRID_GRASP["iterations"],
    PARAM_GRID_GRASP["neighborhood_type"],
    PARAM_GRID_GRASP["ihc_max_iter"],
    PARAM_GRID_GRASP["ihc_stop_no_improve"],
    PARAM_GRID_GRASP["use_delta"],
))

total = len(all_combos) * len(TSP_FILES)
counter = 0

start_total = time.perf_counter()


# ============================================
# GŁÓWNA PĘTLA
# ============================================

for tsp_file in TSP_FILES:
    print(f"\nInstancja: {tsp_file}")
    D = load_tsp_matrix(tsp_file)

    for alpha, iterations, neigh_type, ihc_iter, ihc_noimp, use_delta in all_combos:

        counter += 1
        print(
            f"[{counter}/{total}] "
            f"alpha={alpha}, iter={iterations}, neigh={neigh_type}, "
            f"ihc_iter={ihc_iter}, ihc_noimp={ihc_noimp}, delta={use_delta}"
        )

        params = {
            "alpha": alpha,
            "iterations": iterations,
            "neighborhood_type": neigh_type,
            "ihc_max_iter": ihc_iter,
            "ihc_stop_no_improve": ihc_noimp,
            "use_delta": use_delta,
        }

        # multiprocessing – równolegle REPEATS razy
        with Pool(processes=cpu_count()) as pool:
            parallel_jobs = [
                (solve_tsp, D, params) for _ in range(REPEATS)
            ]
            results_parallel = pool.map(run_single_repeat, parallel_jobs)

        # rozpakowanie wyników
        costs = [c for c, _, _ in results_parallel]
        routes = [r for _, r, _ in results_parallel]
        runtimes = [t for _, _, t in results_parallel]

        # najlepsza trasa
        min_cost = min(costs)
        best_route = routes[costs.index(min_cost)]
        route_str = "-".join(map(str, best_route))

        results.append({
            "instance": tsp_file,
            "alpha": alpha,
            "iterations": iterations,
            "neighborhood_type": neigh_type,
            "ihc_max_iter": ihc_iter,
            "ihc_stop_no_improve": ihc_noimp,
            "use_delta": use_delta,

            "mean_cost": round(np.mean(costs), 3),
            "mean_runtime": np.mean(runtimes),
            "min_cost": round(min_cost, 3),
            "min_route": route_str,
        })


# PODSUMOWANIE

end_total = time.perf_counter()
elapsed = end_total - start_total

print(f"\nŁączny czas eksperymentów: {elapsed/60:.2f} min ({elapsed:.2f} sek)\n")

df = pd.DataFrame(results)
save_experiment_results(df, time_seconds=int(elapsed), subfolder="GRASP")

print("\nNajlepsze parametry dla każdej instancji:")

instances = df["instance"].unique()

for inst in instances:
    sub = df[df["instance"] == inst]
    best_row = sub.loc[sub["mean_cost"].idxmin()]
    print(f"\n{inst}")
    # print(best_row["min_cost"], best_row.to_dict())
    print(f"odległość {best_row["min_cost"]} = {best_row.to_dict()}")
# Out:
# Rozgrzewanie Numba (kompilacja GRASP + IHC-light)...
# Rozgrzewanie zakończone.
#
#
# Instancja: Dane_TSP_48.xlsx
# [1/1296] alpha=0.2, iter=3000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=False
# [2/1296] alpha=0.2, iter=3000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=False
# [3/1296] alpha=0.2, iter=3000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=False
# [4/1296] alpha=0.2, iter=3000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=False
# [5/1296] alpha=0.2, iter=3000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=False
# [6/1296] alpha=0.2, iter=3000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=False
# [7/1296] alpha=0.2, iter=3000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=False
# [8/1296] alpha=0.2, iter=3000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=False
# [9/1296] alpha=0.2, iter=3000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=False
# [10/1296] alpha=0.2, iter=3000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=False
# [11/1296] alpha=0.2, iter=3000, neigh=insert, ihc_iter=4000, ihc_noimp=800, delta=False
# [12/1296] alpha=0.2, iter=3000, neigh=insert, ihc_iter=4000, ihc_noimp=1500, delta=False
# [13/1296] alpha=0.2, iter=3000, neigh=insert, ihc_iter=6000, ihc_noimp=400, delta=False
# [14/1296] alpha=0.2, iter=3000, neigh=insert, ihc_iter=6000, ihc_noimp=800, delta=False
# [15/1296] alpha=0.2, iter=3000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=False
# [16/1296] alpha=0.2, iter=3000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=False
# [17/1296] alpha=0.2, iter=3000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=False
# [18/1296] alpha=0.2, iter=3000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=False
# [19/1296] alpha=0.2, iter=3000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=False
# [20/1296] alpha=0.2, iter=3000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=False
# [21/1296] alpha=0.2, iter=3000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=False
# [22/1296] alpha=0.2, iter=3000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=False
# [23/1296] alpha=0.2, iter=3000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=False
# [24/1296] alpha=0.2, iter=3000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=False
# [25/1296] alpha=0.2, iter=3000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=False
# [26/1296] alpha=0.2, iter=3000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=False
# [27/1296] alpha=0.2, iter=3000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=False
# [28/1296] alpha=0.2, iter=5000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=False
# [29/1296] alpha=0.2, iter=5000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=False
# [30/1296] alpha=0.2, iter=5000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=False
# [31/1296] alpha=0.2, iter=5000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=False
# [32/1296] alpha=0.2, iter=5000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=False
# [33/1296] alpha=0.2, iter=5000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=False
# [34/1296] alpha=0.2, iter=5000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=False
# [35/1296] alpha=0.2, iter=5000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=False
# [36/1296] alpha=0.2, iter=5000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=False
# [37/1296] alpha=0.2, iter=5000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=False
# [38/1296] alpha=0.2, iter=5000, neigh=insert, ihc_iter=4000, ihc_noimp=800, delta=False
# [39/1296] alpha=0.2, iter=5000, neigh=insert, ihc_iter=4000, ihc_noimp=1500, delta=False
# [40/1296] alpha=0.2, iter=5000, neigh=insert, ihc_iter=6000, ihc_noimp=400, delta=False
# [41/1296] alpha=0.2, iter=5000, neigh=insert, ihc_iter=6000, ihc_noimp=800, delta=False
# [42/1296] alpha=0.2, iter=5000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=False
# [43/1296] alpha=0.2, iter=5000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=False
# [44/1296] alpha=0.2, iter=5000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=False
# [45/1296] alpha=0.2, iter=5000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=False
# [46/1296] alpha=0.2, iter=5000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=False
# [47/1296] alpha=0.2, iter=5000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=False
# [48/1296] alpha=0.2, iter=5000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=False
# [49/1296] alpha=0.2, iter=5000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=False
# [50/1296] alpha=0.2, iter=5000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=False
# [51/1296] alpha=0.2, iter=5000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=False
# [52/1296] alpha=0.2, iter=5000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=False
# [53/1296] alpha=0.2, iter=5000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=False
# [54/1296] alpha=0.2, iter=5000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=False
# [55/1296] alpha=0.2, iter=8000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=False
# [56/1296] alpha=0.2, iter=8000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=False
# [57/1296] alpha=0.2, iter=8000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=False
# [58/1296] alpha=0.2, iter=8000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=False
# [59/1296] alpha=0.2, iter=8000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=False
# [60/1296] alpha=0.2, iter=8000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=False
# [61/1296] alpha=0.2, iter=8000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=False
# [62/1296] alpha=0.2, iter=8000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=False
# [63/1296] alpha=0.2, iter=8000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=False
# [64/1296] alpha=0.2, iter=8000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=False
# [65/1296] alpha=0.2, iter=8000, neigh=insert, ihc_iter=4000, ihc_noimp=800, delta=False
# [66/1296] alpha=0.2, iter=8000, neigh=insert, ihc_iter=4000, ihc_noimp=1500, delta=False
# [67/1296] alpha=0.2, iter=8000, neigh=insert, ihc_iter=6000, ihc_noimp=400, delta=False
# [68/1296] alpha=0.2, iter=8000, neigh=insert, ihc_iter=6000, ihc_noimp=800, delta=False
# [69/1296] alpha=0.2, iter=8000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=False
# [70/1296] alpha=0.2, iter=8000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=False
# [71/1296] alpha=0.2, iter=8000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=False
# [72/1296] alpha=0.2, iter=8000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=False
# [73/1296] alpha=0.2, iter=8000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=False
# [74/1296] alpha=0.2, iter=8000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=False
# [75/1296] alpha=0.2, iter=8000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=False
# [76/1296] alpha=0.2, iter=8000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=False
# [77/1296] alpha=0.2, iter=8000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=False
# [78/1296] alpha=0.2, iter=8000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=False
# [79/1296] alpha=0.2, iter=8000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=False
# [80/1296] alpha=0.2, iter=8000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=False
# [81/1296] alpha=0.2, iter=8000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=False
# [82/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=False
# [83/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=False
# [84/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=False
# [85/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=False
# [86/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=False
# [87/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=False
# [88/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=False
# [89/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=False
# [90/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=False
# [91/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=False
# [92/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=4000, ihc_noimp=800, delta=False
# [93/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=4000, ihc_noimp=1500, delta=False
# [94/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=6000, ihc_noimp=400, delta=False
# [95/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=6000, ihc_noimp=800, delta=False
# [96/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=False
# [97/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=False
# [98/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=False
# [99/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=False
# [100/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=False
# [101/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=False
# [102/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=False
# [103/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=False
# [104/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=False
# [105/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=False
# [106/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=False
# [107/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=False
# [108/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=False
# [109/1296] alpha=0.4, iter=3000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=False
# [110/1296] alpha=0.4, iter=3000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=False
# [111/1296] alpha=0.4, iter=3000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=False
# [112/1296] alpha=0.4, iter=3000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=False
# [113/1296] alpha=0.4, iter=3000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=False
# [114/1296] alpha=0.4, iter=3000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=False
# [115/1296] alpha=0.4, iter=3000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=False
# [116/1296] alpha=0.4, iter=3000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=False
# [117/1296] alpha=0.4, iter=3000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=False
# [118/1296] alpha=0.4, iter=3000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=False
# [119/1296] alpha=0.4, iter=3000, neigh=insert, ihc_iter=4000, ihc_noimp=800, delta=False
# [120/1296] alpha=0.4, iter=3000, neigh=insert, ihc_iter=4000, ihc_noimp=1500, delta=False
# [121/1296] alpha=0.4, iter=3000, neigh=insert, ihc_iter=6000, ihc_noimp=400, delta=False
# [122/1296] alpha=0.4, iter=3000, neigh=insert, ihc_iter=6000, ihc_noimp=800, delta=False
# [123/1296] alpha=0.4, iter=3000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=False
# [124/1296] alpha=0.4, iter=3000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=False
# [125/1296] alpha=0.4, iter=3000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=False
# [126/1296] alpha=0.4, iter=3000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=False
# [127/1296] alpha=0.4, iter=3000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=False
# [128/1296] alpha=0.4, iter=3000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=False
# [129/1296] alpha=0.4, iter=3000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=False
# [130/1296] alpha=0.4, iter=3000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=False
# [131/1296] alpha=0.4, iter=3000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=False
# [132/1296] alpha=0.4, iter=3000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=False
# [133/1296] alpha=0.4, iter=3000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=False
# [134/1296] alpha=0.4, iter=3000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=False
# [135/1296] alpha=0.4, iter=3000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=False
# [136/1296] alpha=0.4, iter=5000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=False
# [137/1296] alpha=0.4, iter=5000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=False
# [138/1296] alpha=0.4, iter=5000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=False
# [139/1296] alpha=0.4, iter=5000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=False
# [140/1296] alpha=0.4, iter=5000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=False
# [141/1296] alpha=0.4, iter=5000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=False
# [142/1296] alpha=0.4, iter=5000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=False
# [143/1296] alpha=0.4, iter=5000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=False
# [144/1296] alpha=0.4, iter=5000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=False
# [145/1296] alpha=0.4, iter=5000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=False
# [146/1296] alpha=0.4, iter=5000, neigh=insert, ihc_iter=4000, ihc_noimp=800, delta=False
# [147/1296] alpha=0.4, iter=5000, neigh=insert, ihc_iter=4000, ihc_noimp=1500, delta=False
# [148/1296] alpha=0.4, iter=5000, neigh=insert, ihc_iter=6000, ihc_noimp=400, delta=False
# [149/1296] alpha=0.4, iter=5000, neigh=insert, ihc_iter=6000, ihc_noimp=800, delta=False
# [150/1296] alpha=0.4, iter=5000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=False
# [151/1296] alpha=0.4, iter=5000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=False
# [152/1296] alpha=0.4, iter=5000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=False
# [153/1296] alpha=0.4, iter=5000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=False
# [154/1296] alpha=0.4, iter=5000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=False
# [155/1296] alpha=0.4, iter=5000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=False
# [156/1296] alpha=0.4, iter=5000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=False
# [157/1296] alpha=0.4, iter=5000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=False
# [158/1296] alpha=0.4, iter=5000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=False
# [159/1296] alpha=0.4, iter=5000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=False
# [160/1296] alpha=0.4, iter=5000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=False
# [161/1296] alpha=0.4, iter=5000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=False
# [162/1296] alpha=0.4, iter=5000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=False
# [163/1296] alpha=0.4, iter=8000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=False
# [164/1296] alpha=0.4, iter=8000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=False
# [165/1296] alpha=0.4, iter=8000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=False
# [166/1296] alpha=0.4, iter=8000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=False
# [167/1296] alpha=0.4, iter=8000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=False
# [168/1296] alpha=0.4, iter=8000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=False
# [169/1296] alpha=0.4, iter=8000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=False
# [170/1296] alpha=0.4, iter=8000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=False
# [171/1296] alpha=0.4, iter=8000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=False
# [172/1296] alpha=0.4, iter=8000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=False
# [173/1296] alpha=0.4, iter=8000, neigh=insert, ihc_iter=4000, ihc_noimp=800, delta=False
# [174/1296] alpha=0.4, iter=8000, neigh=insert, ihc_iter=4000, ihc_noimp=1500, delta=False
# [175/1296] alpha=0.4, iter=8000, neigh=insert, ihc_iter=6000, ihc_noimp=400, delta=False
# [176/1296] alpha=0.4, iter=8000, neigh=insert, ihc_iter=6000, ihc_noimp=800, delta=False
# [177/1296] alpha=0.4, iter=8000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=False
# [178/1296] alpha=0.4, iter=8000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=False
# [179/1296] alpha=0.4, iter=8000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=False
# [180/1296] alpha=0.4, iter=8000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=False
# [181/1296] alpha=0.4, iter=8000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=False
# [182/1296] alpha=0.4, iter=8000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=False
# [183/1296] alpha=0.4, iter=8000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=False
# [184/1296] alpha=0.4, iter=8000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=False
# [185/1296] alpha=0.4, iter=8000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=False
# [186/1296] alpha=0.4, iter=8000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=False
# [187/1296] alpha=0.4, iter=8000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=False
# [188/1296] alpha=0.4, iter=8000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=False
# [189/1296] alpha=0.4, iter=8000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=False
# [190/1296] alpha=0.4, iter=10000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=False
# [191/1296] alpha=0.4, iter=10000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=False
# [192/1296] alpha=0.4, iter=10000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=False
# [193/1296] alpha=0.4, iter=10000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=False
# [194/1296] alpha=0.4, iter=10000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=False
# [195/1296] alpha=0.4, iter=10000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=False
# [196/1296] alpha=0.4, iter=10000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=False
# [197/1296] alpha=0.4, iter=10000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=False
# [198/1296] alpha=0.4, iter=10000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=False
# [199/1296] alpha=0.4, iter=10000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=False
# [200/1296] alpha=0.4, iter=10000, neigh=insert, ihc_iter=4000, ihc_noimp=800, delta=False
# [201/1296] alpha=0.4, iter=10000, neigh=insert, ihc_iter=4000, ihc_noimp=1500, delta=False
# [202/1296] alpha=0.4, iter=10000, neigh=insert, ihc_iter=6000, ihc_noimp=400, delta=False
# [203/1296] alpha=0.4, iter=10000, neigh=insert, ihc_iter=6000, ihc_noimp=800, delta=False
# [204/1296] alpha=0.4, iter=10000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=False
# [205/1296] alpha=0.4, iter=10000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=False
# [206/1296] alpha=0.4, iter=10000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=False
# [207/1296] alpha=0.4, iter=10000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=False
# [208/1296] alpha=0.4, iter=10000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=False
# [209/1296] alpha=0.4, iter=10000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=False
# [210/1296] alpha=0.4, iter=10000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=False
# [211/1296] alpha=0.4, iter=10000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=False
# [212/1296] alpha=0.4, iter=10000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=False
# [213/1296] alpha=0.4, iter=10000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=False
# [214/1296] alpha=0.4, iter=10000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=False
# [215/1296] alpha=0.4, iter=10000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=False
# [216/1296] alpha=0.4, iter=10000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=False
# [217/1296] alpha=0.6, iter=3000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=False
# [218/1296] alpha=0.6, iter=3000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=False
# [219/1296] alpha=0.6, iter=3000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=False
# [220/1296] alpha=0.6, iter=3000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=False
# [221/1296] alpha=0.6, iter=3000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=False
# [222/1296] alpha=0.6, iter=3000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=False
# [223/1296] alpha=0.6, iter=3000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=False
# [224/1296] alpha=0.6, iter=3000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=False
# [225/1296] alpha=0.6, iter=3000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=False
# [226/1296] alpha=0.6, iter=3000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=False
#
1296] alpha=0.8, iter=5000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=False
# [1217/1296] alpha=0.8, iter=5000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=False
# [1218/1296] alpha=0.8, iter=5000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=False
# [1219/1296] alpha=0.8, iter=5000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=False
# [1220/1296] alpha=0.8, iter=5000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=False
# [1221/1296] alpha=0.8, iter=5000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=False
# [1222/1296] alpha=0.8, iter=5000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=False
# [1223/1296] alpha=0.8, iter=5000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=False
# [1224/1296] alpha=0.8, iter=5000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=False
# [1225/1296] alpha=0.8, iter=5000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=False
# [1226/1296] alpha=0.8, iter=5000, neigh=insert, ihc_iter=4000, ihc_noimp=800, delta=False
# [1227/1296] alpha=0.8, iter=5000, neigh=insert, ihc_iter=4000, ihc_noimp=1500, delta=False
# [1228/1296] alpha=0.8, iter=5000, neigh=insert, ihc_iter=6000, ihc_noimp=400, delta=False
# [1229/1296] alpha=0.8, iter=5000, neigh=insert, ihc_iter=6000, ihc_noimp=800, delta=False
# [1230/1296] alpha=0.8, iter=5000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=False
# [1231/1296] alpha=0.8, iter=5000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=False
# [1232/1296] alpha=0.8, iter=5000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=False
# [1233/1296] alpha=0.8, iter=5000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=False
# [1234/1296] alpha=0.8, iter=5000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=False
# [1235/1296] alpha=0.8, iter=5000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=False
# [1236/1296] alpha=0.8, iter=5000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=False
# [1237/1296] alpha=0.8, iter=5000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=False
# [1238/1296] alpha=0.8, iter=5000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=False
# [1239/1296] alpha=0.8, iter=5000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=False
# [1240/1296] alpha=0.8, iter=5000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=False
# [1241/1296] alpha=0.8, iter=5000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=False
# [1242/1296] alpha=0.8, iter=5000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=False
# [1243/1296] alpha=0.8, iter=8000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=False
# [1244/1296] alpha=0.8, iter=8000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=False
# [1245/1296] alpha=0.8, iter=8000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=False
# [1246/1296] alpha=0.8, iter=8000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=False
# [1247/1296] alpha=0.8, iter=8000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=False
# [1248/1296] alpha=0.8, iter=8000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=False
# [1249/1296] alpha=0.8, iter=8000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=False
# [1250/1296] alpha=0.8, iter=8000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=False
# [1251/1296] alpha=0.8, iter=8000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=False
# [1252/1296] alpha=0.8, iter=8000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=False
# [1253/1296] alpha=0.8, iter=8000, neigh=insert, ihc_iter=4000, ihc_noimp=800, delta=False
# [1254/1296] alpha=0.8, iter=8000, neigh=insert, ihc_iter=4000, ihc_noimp=1500, delta=False
# [1255/1296] alpha=0.8, iter=8000, neigh=insert, ihc_iter=6000, ihc_noimp=400, delta=False
# [1256/1296] alpha=0.8, iter=8000, neigh=insert, ihc_iter=6000, ihc_noimp=800, delta=False
# [1257/1296] alpha=0.8, iter=8000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=False
# [1258/1296] alpha=0.8, iter=8000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=False
# [1259/1296] alpha=0.8, iter=8000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=False
# [1260/1296] alpha=0.8, iter=8000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=False
# [1261/1296] alpha=0.8, iter=8000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=False
# [1262/1296] alpha=0.8, iter=8000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=False
# [1263/1296] alpha=0.8, iter=8000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=False
# [1264/1296] alpha=0.8, iter=8000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=False
# [1265/1296] alpha=0.8, iter=8000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=False
# [1266/1296] alpha=0.8, iter=8000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=False
# [1267/1296] alpha=0.8, iter=8000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=False
# [1268/1296] alpha=0.8, iter=8000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=False
# [1269/1296] alpha=0.8, iter=8000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=False
# [1270/1296] alpha=0.8, iter=10000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=False
# [1271/1296] alpha=0.8, iter=10000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=False
# [1272/1296] alpha=0.8, iter=10000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=False
# [1273/1296] alpha=0.8, iter=10000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=False
# [1274/1296] alpha=0.8, iter=10000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=False
# [1275/1296] alpha=0.8, iter=10000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=False
# [1276/1296] alpha=0.8, iter=10000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=False
# [1277/1296] alpha=0.8, iter=10000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=False
# [1278/1296] alpha=0.8, iter=10000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=False
# [1279/1296] alpha=0.8, iter=10000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=False
# [1280/1296] alpha=0.8, iter=10000, neigh=insert, ihc_iter=4000, ihc_noimp=800, delta=False
# [1281/1296] alpha=0.8, iter=10000, neigh=insert, ihc_iter=4000, ihc_noimp=1500, delta=False
# [1282/1296] alpha=0.8, iter=10000, neigh=insert, ihc_iter=6000, ihc_noimp=400, delta=False
# [1283/1296] alpha=0.8, iter=10000, neigh=insert, ihc_iter=6000, ihc_noimp=800, delta=False
# [1284/1296] alpha=0.8, iter=10000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=False
# [1285/1296] alpha=0.8, iter=10000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=False
# [1286/1296] alpha=0.8, iter=10000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=False
# [1287/1296] alpha=0.8, iter=10000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=False
# [1288/1296] alpha=0.8, iter=10000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=False
# [1289/1296] alpha=0.8, iter=10000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=False
# [1290/1296] alpha=0.8, iter=10000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=False
# [1291/1296] alpha=0.8, iter=10000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=False
# [1292/1296] alpha=0.8, iter=10000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=False
# [1293/1296] alpha=0.8, iter=10000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=False
# [1294/1296] alpha=0.8, iter=10000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=False
# [1295/1296] alpha=0.8, iter=10000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=False
# [1296/1296] alpha=0.8, iter=10000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=False
#
# Łączny czas eksperymentów: 865.96 min (51957.59 sek)
#
#
# Podsumowanie (pierwsze 20 wierszy):
#         instance  alpha  iterations neighborhood_type  ihc_max_iter  ihc_stop_no_improve  use_delta  mean_cost  mean_runtime  min_cost                                                                                                                                min_route
# Dane_TSP_48.xlsx    0.4       10000           two_opt          8000                  800      False     9843.0     37.157251    9809.0 36-28-30-6-37-19-27-43-17-0-4-26-35-45-10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7
# Dane_TSP_48.xlsx    0.2        5000           two_opt          4000                 1500      False     9874.2     20.196140    9809.0 29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30-6-37-19-27-43-17-0-4-26-35-45-10-24-42-2
# Dane_TSP_48.xlsx    0.2        5000           two_opt          6000                  800      False     9857.8     20.034093    9809.0 26-35-45-10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30-6-37-19-27-43-17-0-4
# Dane_TSP_48.xlsx    0.2        5000           two_opt          6000                 1500      False     9829.8     22.161630    9809.0 29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30-6-37-19-27-43-17-0-4-26-35-45-10-24-42-2
# Dane_TSP_48.xlsx    0.2        5000           two_opt          8000                  800      False     9855.4     19.332799    9809.0 26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35
# Dane_TSP_48.xlsx    0.2        5000           two_opt          8000                 1500      False     9823.0     25.584153    9809.0 0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35-26-4
# Dane_TSP_48.xlsx    0.2        8000           two_opt          6000                  800      False     9835.2     32.558917    9809.0 16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30-6-37-19-27-43-17-0-4-26-35-45-10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41
# Dane_TSP_48.xlsx    0.2        8000           two_opt          6000                 1500      False     9813.8     39.616153    9809.0 10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30-6-37-19-27-43-17-0-4-26-35-45
# Dane_TSP_48.xlsx    0.2        8000           two_opt          8000                 1500      False     9816.8     38.447970    9809.0 11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35-26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12
# Dane_TSP_48.xlsx    0.2       10000           two_opt          6000                 1500      False     9830.0     86.245677    9809.0 26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35
# Dane_TSP_48.xlsx    0.2       10000           two_opt          8000                 1500      False     9816.2     52.537972    9809.0 45-10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30-6-37-19-27-43-17-0-4-26-35
# Dane_TSP_48.xlsx    0.4        3000           two_opt          8000                 1500      False     9838.0     20.082619    9809.0 6-37-19-27-43-17-0-4-26-35-45-10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30
# Dane_TSP_48.xlsx    0.4        5000           two_opt          6000                  800      False     9828.0     27.395316    9809.0 19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35-26-4-0-17-43-27
# Dane_TSP_48.xlsx    0.4        5000           two_opt          8000                 1500      False     9831.8     24.804984    9809.0 0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35-26-4
# Dane_TSP_48.xlsx    0.4        8000           two_opt          8000                 1500      False     9825.4     38.035089    9809.0 42-24-10-45-35-26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2
# Dane_TSP_48.xlsx    0.2        5000           two_opt          4000                  800      False     9897.6     20.605503    9809.0 26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35
# Dane_TSP_48.xlsx    0.4       10000           two_opt          6000                  400      False     9879.6     29.651215    9809.0 43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35-26-4-0-17
# Dane_TSP_48.xlsx    0.6        5000           two_opt          6000                 1500      False     9834.8     22.278737    9809.0 35-26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45
# Dane_TSP_48.xlsx    0.6        5000           two_opt          8000                  800      False     9858.6     19.918077    9809.0 43-17-0-4-26-35-45-10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30-6-37-19-27
# Dane_TSP_48.xlsx    0.6        5000           two_opt          8000                 1500      False     9817.6     24.693997    9809.0 0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35-26-4
#
# Najlepsze parametry dla każdej instancji:
#
# Dane_TSP_48.xlsx
# odległość 9809.0 = {'instance': 'Dane_TSP_48.xlsx', 'alpha': 0.2, 'iterations': 8000, 'neighborhood_type': 'two_opt', 'ihc_max_iter': 6000, 'ihc_stop_no_improve': 1500, 'use_delta': False, 'mean_cost': 9813.8, 'mean_runtime': 39.61615324020386, 'min_cost': 9809.0, 'min_route': '10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30-6-37-19-27-43-17-0-4-26-35-45'}
#
# Dane_TSP_76.xlsx
# odległość 98412.19 = {'instance': 'Dane_TSP_76.xlsx', 'alpha': 0.2, 'iterations': 8000, 'neighborhood_type': 'two_opt', 'ihc_max_iter': 8000, 'ihc_stop_no_improve': 1500, 'use_delta': False, 'mean_cost': 99424.996, 'mean_runtime': 60.697998237609866, 'min_cost': 98412.19, 'min_route': '2-3-4-6-7-8-9-10-5-20-19-31-30-29-26-27-28-32-33-43-42-54-53-52-55-56-51-49-50-66-65-71-72-73-64-63-62-61-57-58-59-60-41-40-34-35-39-38-36-37-18-17-16-15-11-12-13-14-74-0-70-67-68-69-47-48-44-45-46-24-25-21-22-23-1-75-76'}
#
# Dane_TSP_127.xlsx
# odległość 128372.465 = {'instance': 'Dane_TSP_127.xlsx', 'alpha': 0.2, 'iterations': 10000, 'neighborhood_type': 'two_opt', 'ihc_max_iter': 8000, 'ihc_stop_no_improve': 1500, 'use_delta': False, 'mean_cost': 129729.831, 'mean_runtime': 103.98796963691711, 'min_cost': 128372.465, 'min_route': '99-92-89-113-64-58-91-62-61-116-9-6-106-114-7-120-105-15-20-12-14-41-30-1-16-37-36-35-44-45-103-0-98-97-123-95-93-127-107-111-112-94-46-118-48-53-49-47-54-56-121-5-52-124-55-66-100-10-115-13-50-51-2-57-40-34-43-38-39-26-25-33-122-28-29-32-42-27-31-80-79-77-18-73-68-76-78-117-81-84-126-82-83-101-102-63-119-96-109-88-87-86-85-110-71-70-69-75-74-67-72-21-17-23-24-8-19-22-4-108-11-3-90-60-59-104-125-65'}
