# %%
# GRASP – SKRYPT EKSPERYMENTALNY
# Uruchamia serię eksperymentów dla algorytmu GRASP z różnymi
# parametrami. Struktura analogiczna do IHC, TS, SA itd.
#
# Wymagane:
#   - solve_tsp() z grasp_numba
#   - run_single_repeat()
#   - save_experiment_results()
#   - load_tsp_matrix()

# %load_ext autoreload
# %autoreload 2

import time
import pandas as pd
import numpy as np
import itertools
from multiprocessing import Pool, cpu_count

from src.utils.tsp_loader import load_tsp_matrix
from src.algorithms.grasp_numba import solve_tsp
from src.utils.run_single_repeat import run_single_repeat
from src.utils.result_saver import save_experiment_results


# USTAWIENIA EKSPERYMENTU

TSP_FILES = ["Dane_TSP_48.xlsx", "Dane_TSP_76.xlsx", "Dane_TSP_127.xlsx"]
# TSP_FILES = ["Dane_TSP_48.xlsx"]

PARAM_GRID_GRASP = {
    "alpha": [0.2, 0.4, 0.6, 0.8],
    "iterations": [3_000, 5_000, 8_000, 10_000],
    "neighborhood_type": ["swap", "insert", "two_opt"],
    # parametry local-search (IHC-light)
    "ihc_max_iter": [4_000, 6_000, 8_000],
    "ihc_stop_no_improve": [400, 800, 1_500],
    "use_delta": [True], # zawsze delta
}

REPEATS = 5
results = []


# ROZGRZANIE

print("Rozgrzewanie Numba (kompilacja GRASP + IHC-light)...")

D_tmp = load_tsp_matrix(TSP_FILES[0])

# poprawna rozgrzewka: solve_tsp wymaga neighborhood_type jako string
_ = solve_tsp(D_tmp, {
    "alpha": 0.3,
    "iterations": 2,
    "neighborhood_type": "swap",
    "ihc_max_iter": 50,
    "ihc_stop_no_improve": 10,
    "use_delta": True,
})

print("Rozgrzewanie zakończone.\n")


# LISTA KOMBINACJI PARAMETRÓW

all_combos = list(itertools.product(
    PARAM_GRID_GRASP["alpha"],
    PARAM_GRID_GRASP["iterations"],
    PARAM_GRID_GRASP["neighborhood_type"],
    PARAM_GRID_GRASP["ihc_max_iter"],
    PARAM_GRID_GRASP["ihc_stop_no_improve"],
    PARAM_GRID_GRASP["use_delta"],
))

total = len(all_combos) * len(TSP_FILES)
counter = 0

start_total = time.perf_counter()


# ============================================
# GŁÓWNA PĘTLA
# ============================================

for tsp_file in TSP_FILES:
    print(f"\nInstancja: {tsp_file}")
    D = load_tsp_matrix(tsp_file)

    for alpha, iterations, neigh_type, ihc_iter, ihc_noimp, use_delta in all_combos:

        counter += 1
        print(
            f"[{counter}/{total}] "
            f"alpha={alpha}, iter={iterations}, neigh={neigh_type}, "
            f"ihc_iter={ihc_iter}, ihc_noimp={ihc_noimp}, delta={use_delta}"
        )

        params = {
            "alpha": alpha,
            "iterations": iterations,
            "neighborhood_type": neigh_type,
            "ihc_max_iter": ihc_iter,
            "ihc_stop_no_improve": ihc_noimp,
            "use_delta": use_delta,
        }

        # multiprocessing – równolegle REPEATS razy
        with Pool(processes=cpu_count()) as pool:
            parallel_jobs = [
                (solve_tsp, D, params) for _ in range(REPEATS)
            ]
            results_parallel = pool.map(run_single_repeat, parallel_jobs)

        # rozpakowanie wyników
        costs = [c for c, _, _ in results_parallel]
        routes = [r for _, r, _ in results_parallel]
        runtimes = [t for _, _, t in results_parallel]

        # najlepsza trasa
        min_cost = min(costs)
        best_route = routes[costs.index(min_cost)]
        route_str = "-".join(map(str, best_route))

        results.append({
            "instance": tsp_file,
            "alpha": alpha,
            "iterations": iterations,
            "neighborhood_type": neigh_type,
            "ihc_max_iter": ihc_iter,
            "ihc_stop_no_improve": ihc_noimp,
            "use_delta": use_delta,

            "mean_cost": round(np.mean(costs), 3),
            "mean_runtime": np.mean(runtimes),
            "min_cost": round(min_cost, 3),
            "min_route": route_str,
        })


# PODSUMOWANIE

end_total = time.perf_counter()
elapsed = end_total - start_total

print(f"\nŁączny czas eksperymentów: {elapsed/60:.2f} min ({elapsed:.2f} sek)\n")

df = pd.DataFrame(results)
save_experiment_results(df, time_seconds=int(elapsed), subfolder="GRASP")

print("\nNajlepsze parametry dla każdej instancji:")

instances = df["instance"].unique()

for inst in instances:
    sub = df[df["instance"] == inst]
    best_row = sub.loc[sub["mean_cost"].idxmin()]
    print(f"\n{inst}")
    # print(best_row["min_cost"], best_row.to_dict())
    print(f"odległość {best_row["min_cost"]} = {best_row.to_dict()}")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Rozgrzewanie Numba (kompilacja GRASP + IHC-light)...
# Rozgrzewanie zakończone.
#
#
# Instancja: Dane_TSP_48.xlsx
# [1/1296] alpha=0.2, iter=3000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=True
# [2/1296] alpha=0.2, iter=3000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=True
# [3/1296] alpha=0.2, iter=3000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=True
# [4/1296] alpha=0.2, iter=3000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=True
# [5/1296] alpha=0.2, iter=3000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=True
# [6/1296] alpha=0.2, iter=3000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=True
# [7/1296] alpha=0.2, iter=3000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=True
# [8/1296] alpha=0.2, iter=3000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=True
# [9/1296] alpha=0.2, iter=3000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=True
# [10/1296] alpha=0.2, iter=3000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=True
# [11/1296] alpha=0.2, iter=3000, neigh=insert, ihc_iter=4000, ihc_noimp=800, delta=True
# [12/1296] alpha=0.2, iter=3000, neigh=insert, ihc_iter=4000, ihc_noimp=1500, delta=True
# [13/1296] alpha=0.2, iter=3000, neigh=insert, ihc_iter=6000, ihc_noimp=400, delta=True
# [14/1296] alpha=0.2, iter=3000, neigh=insert, ihc_iter=6000, ihc_noimp=800, delta=True
# [15/1296] alpha=0.2, iter=3000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=True
# [16/1296] alpha=0.2, iter=3000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=True
# [17/1296] alpha=0.2, iter=3000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=True
# [18/1296] alpha=0.2, iter=3000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=True
# [19/1296] alpha=0.2, iter=3000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=True
# [20/1296] alpha=0.2, iter=3000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=True
# [21/1296] alpha=0.2, iter=3000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=True
# [22/1296] alpha=0.2, iter=3000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=True
# [23/1296] alpha=0.2, iter=3000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=True
# [24/1296] alpha=0.2, iter=3000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=True
# [25/1296] alpha=0.2, iter=3000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=True
# [26/1296] alpha=0.2, iter=3000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=True
# [27/1296] alpha=0.2, iter=3000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=True
# [28/1296] alpha=0.2, iter=5000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=True
# [29/1296] alpha=0.2, iter=5000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=True
# [30/1296] alpha=0.2, iter=5000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=True
# [31/1296] alpha=0.2, iter=5000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=True
# [32/1296] alpha=0.2, iter=5000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=True
# [33/1296] alpha=0.2, iter=5000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=True
# [34/1296] alpha=0.2, iter=5000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=True
# [35/1296] alpha=0.2, iter=5000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=True
# [36/1296] alpha=0.2, iter=5000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=True
# [37/1296] alpha=0.2, iter=5000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=True
# [38/1296] alpha=0.2, iter=5000, neigh=insert, ihc_iter=4000, ihc_noimp=800, delta=True
# [39/1296] alpha=0.2, iter=5000, neigh=insert, ihc_iter=4000, ihc_noimp=1500, delta=True
# [40/1296] alpha=0.2, iter=5000, neigh=insert, ihc_iter=6000, ihc_noimp=400, delta=True
# [41/1296] alpha=0.2, iter=5000, neigh=insert, ihc_iter=6000, ihc_noimp=800, delta=True
# [42/1296] alpha=0.2, iter=5000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=True
# [43/1296] alpha=0.2, iter=5000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=True
# [44/1296] alpha=0.2, iter=5000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=True
# [45/1296] alpha=0.2, iter=5000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=True
# [46/1296] alpha=0.2, iter=5000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=True
# [47/1296] alpha=0.2, iter=5000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=True
# [48/1296] alpha=0.2, iter=5000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=True
# [49/1296] alpha=0.2, iter=5000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=True
# [50/1296] alpha=0.2, iter=5000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=True
# [51/1296] alpha=0.2, iter=5000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=True
# [52/1296] alpha=0.2, iter=5000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=True
# [53/1296] alpha=0.2, iter=5000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=True
# [54/1296] alpha=0.2, iter=5000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=True
# [55/1296] alpha=0.2, iter=8000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=True
# [56/1296] alpha=0.2, iter=8000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=True
# [57/1296] alpha=0.2, iter=8000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=True
# [58/1296] alpha=0.2, iter=8000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=True
# [59/1296] alpha=0.2, iter=8000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=True
# [60/1296] alpha=0.2, iter=8000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=True
# [61/1296] alpha=0.2, iter=8000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=True
# [62/1296] alpha=0.2, iter=8000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=True
# [63/1296] alpha=0.2, iter=8000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=True
# [64/1296] alpha=0.2, iter=8000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=True
# [65/1296] alpha=0.2, iter=8000, neigh=insert, ihc_iter=4000, ihc_noimp=800, delta=True
# [66/1296] alpha=0.2, iter=8000, neigh=insert, ihc_iter=4000, ihc_noimp=1500, delta=True
# [67/1296] alpha=0.2, iter=8000, neigh=insert, ihc_iter=6000, ihc_noimp=400, delta=True
# [68/1296] alpha=0.2, iter=8000, neigh=insert, ihc_iter=6000, ihc_noimp=800, delta=True
# [69/1296] alpha=0.2, iter=8000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=True
# [70/1296] alpha=0.2, iter=8000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=True
# [71/1296] alpha=0.2, iter=8000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=True
# [72/1296] alpha=0.2, iter=8000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=True
# [73/1296] alpha=0.2, iter=8000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=True
# [74/1296] alpha=0.2, iter=8000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=True
# [75/1296] alpha=0.2, iter=8000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=True
# [76/1296] alpha=0.2, iter=8000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=True
# [77/1296] alpha=0.2, iter=8000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=True
# [78/1296] alpha=0.2, iter=8000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=True
# [79/1296] alpha=0.2, iter=8000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=True
# [80/1296] alpha=0.2, iter=8000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=True
# [81/1296] alpha=0.2, iter=8000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=True
# [82/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=True
# [83/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=True
# [84/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=True
# [85/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=True
# [86/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=True
# [87/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=True
# [88/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=True
# [89/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=True
# [90/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=True
# [91/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=True
# [92/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=4000, ihc_noimp=800, delta=True
# [93/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=4000, ihc_noimp=1500, delta=True
# [94/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=6000, ihc_noimp=400, delta=True
# [95/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=6000, ihc_noimp=800, delta=True
# [96/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=True
# [97/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=True
# [98/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=True
# [99/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=True
# [100/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=True
# [101/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=True
# [102/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=True
# [103/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=True
# [104/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=True
# [105/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=True
# [106/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=True
# [107/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=True
# [108/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=True
# [109/1296] alpha=0.4, iter=3000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=True
# [110/1296] alpha=0.4, iter=3000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=True
# [111/1296] alpha=0.4, iter=3000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=True
# [112/1296] alpha=0.4, iter=3000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=True
# [113/1296] alpha=0.4, iter=3000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=True
# [114/1296] alpha=0.4, iter=3000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=True
# [115/1296] alpha=0.4, iter=3000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=True
# [116/1296] alpha=0.4, iter=3000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=True
# [117/1296] alpha=0.4, iter=3000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=True
# [118/1296] alpha=0.4, iter=3000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=True
# [119/1296] alpha=0.4, iter=3000, neigh=insert, ihc_iter=4000, ihc_noimp=800, delta=True
# [120/1296] alpha=0.4, iter=3000, neigh=insert, ihc_iter=4000, ihc_noimp=1500, delta=True
# [121/1296] alpha=0.4, iter=3000, neigh=insert, ihc_iter=6000, ihc_noimp=400, delta=True
# [122/1296] alpha=0.4, iter=3000, neigh=insert, ihc_iter=6000, ihc_noimp=800, delta=True
# [123/1296] alpha=0.4, iter=3000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=True
# [124/1296] alpha=0.4, iter=3000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=True
# [125/1296] alpha=0.4, iter=3000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=True
# [126/1296] alpha=0.4, iter=3000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=True
# [127/1296] alpha=0.4, iter=3000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=True
# [128/1296] alpha=0.4, iter=3000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=True
# [129/1296] alpha=0.4, iter=3000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=True
# [130/1296] alpha=0.4, iter=3000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=True
# [131/1296] alpha=0.4, iter=3000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=True
# [132/1296] alpha=0.4, iter=3000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=True
# [133/1296] alpha=0.4, iter=3000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=True
# [134/1296] alpha=0.4, iter=3000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=True
# [135/1296] alpha=0.4, iter=3000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=True
# [136/1296] alpha=0.4, iter=5000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=True
# [137/1296] alpha=0.4, iter=5000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=True
# [138/1296] alpha=0.4, iter=5000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=True
# [139/1296] alpha=0.4, iter=5000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=True
# [140/1296] alpha=0.4, iter=5000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=True
# [141/1296] alpha=0.4, iter=5000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=True
# [142/1296] alpha=0.4, iter=5000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=True
# [143/1296] alpha=0.4, iter=5000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=True
# [144/1296] alpha=0.4, iter=5000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=True
# [145/1296] alpha=0.4, iter=5000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=True
# [146/1296] alpha=0.4, iter=5000, neigh=insert, ihc_iter=4000, ihc_noimp=800, delta=True
# [147/1296] alpha=0.4, iter=5000, neigh=insert, ihc_iter=4000, ihc_noimp=1500, delta=True
# [148/1296] alpha=0.4, iter=5000, neigh=insert, ihc_iter=6000, ihc_noimp=400, delta=True
# [149/1296] alpha=0.4, iter=5000, neigh=insert, ihc_iter=6000, ihc_noimp=800, delta=True
# [150/1296] alpha=0.4, iter=5000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=True
# [151/1296] alpha=0.4, iter=5000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=True
# [152/1296] alpha=0.4, iter=5000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=True
# [153/1296] alpha=0.4, iter=5000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=True
# [154/1296] alpha=0.4, iter=5000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=True
# [155/1296] alpha=0.4, iter=5000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=True
# [156/1296] alpha=0.4, iter=5000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=True
# [157/1296] alpha=0.4, iter=5000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=True
# [158/1296] alpha=0.4, iter=5000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=True
# [159/1296] alpha=0.4, iter=5000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=True
# [160/1296] alpha=0.4, iter=5000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=True
# [161/1296] alpha=0.4, iter=5000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=True
# [162/1296] alpha=0.4, iter=5000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=True
# [163/1296] alpha=0.4, iter=8000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=True
# [164/1296] alpha=0.4, iter=8000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=True
# [165/1296] alpha=0.4, iter=8000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=True
# [166/1296] alpha=0.4, iter=8000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=True
#
1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=True
# [519/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=True
# [520/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=True
# [521/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=True
# [522/1296] alpha=0.2, iter=10000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=True
# [523/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=True
# [524/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=4000, ihc_noimp=800, delta=True
# [525/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=4000, ihc_noimp=1500, delta=True
# [526/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=6000, ihc_noimp=400, delta=True
# [527/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=6000, ihc_noimp=800, delta=True
# [528/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=True
# [529/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=True
# [530/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=True
# [531/1296] alpha=0.2, iter=10000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=True
# [532/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=True
# [533/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=True
# [534/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=True
# [535/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=True
# [536/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=True
# [537/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=True
# [538/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=True
# [539/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=True
# [540/1296] alpha=0.2, iter=10000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=True
# [541/1296] alpha=0.4, iter=3000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=True
# [542/1296] alpha=0.4, iter=3000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=True
# ...
# [1203/1296] alpha=0.8, iter=3000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=True
# [1204/1296] alpha=0.8, iter=3000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=True
# [1205/1296] alpha=0.8, iter=3000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=True
# [1206/1296] alpha=0.8, iter=3000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=True
# [1207/1296] alpha=0.8, iter=3000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=True
# [1208/1296] alpha=0.8, iter=3000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=True
# [1209/1296] alpha=0.8, iter=3000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=True
# [1210/1296] alpha=0.8, iter=3000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=True
# [1211/1296] alpha=0.8, iter=3000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=True
# [1212/1296] alpha=0.8, iter=3000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=True
# [1213/1296] alpha=0.8, iter=3000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=True
# [1214/1296] alpha=0.8, iter=3000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=True
# [1215/1296] alpha=0.8, iter=3000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=True
# [1216/1296] alpha=0.8, iter=5000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=True
# [1217/1296] alpha=0.8, iter=5000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=True
# [1218/1296] alpha=0.8, iter=5000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=True
# [1219/1296] alpha=0.8, iter=5000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=True
# [1220/1296] alpha=0.8, iter=5000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=True
# [1221/1296] alpha=0.8, iter=5000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=True
# [1222/1296] alpha=0.8, iter=5000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=True
# [1223/1296] alpha=0.8, iter=5000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=True
# [1224/1296] alpha=0.8, iter=5000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=True
# [1225/1296] alpha=0.8, iter=5000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=True
# [1226/1296] alpha=0.8, iter=5000, neigh=insert, ihc_iter=4000, ihc_noimp=800, delta=True
# [1227/1296] alpha=0.8, iter=5000, neigh=insert, ihc_iter=4000, ihc_noimp=1500, delta=True
# [1228/1296] alpha=0.8, iter=5000, neigh=insert, ihc_iter=6000, ihc_noimp=400, delta=True
# [1229/1296] alpha=0.8, iter=5000, neigh=insert, ihc_iter=6000, ihc_noimp=800, delta=True
# [1230/1296] alpha=0.8, iter=5000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=True
# [1231/1296] alpha=0.8, iter=5000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=True
# [1232/1296] alpha=0.8, iter=5000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=True
# [1233/1296] alpha=0.8, iter=5000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=True
# [1234/1296] alpha=0.8, iter=5000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=True
# [1235/1296] alpha=0.8, iter=5000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=True
# [1236/1296] alpha=0.8, iter=5000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=True
# [1237/1296] alpha=0.8, iter=5000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=True
# [1238/1296] alpha=0.8, iter=5000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=True
# [1239/1296] alpha=0.8, iter=5000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=True
# [1240/1296] alpha=0.8, iter=5000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=True
# [1241/1296] alpha=0.8, iter=5000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=True
# [1242/1296] alpha=0.8, iter=5000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=True
# [1243/1296] alpha=0.8, iter=8000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=True
# [1244/1296] alpha=0.8, iter=8000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=True
# [1245/1296] alpha=0.8, iter=8000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=True
# [1246/1296] alpha=0.8, iter=8000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=True
# [1247/1296] alpha=0.8, iter=8000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=True
# [1248/1296] alpha=0.8, iter=8000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=True
# [1249/1296] alpha=0.8, iter=8000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=True
# [1250/1296] alpha=0.8, iter=8000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=True
# [1251/1296] alpha=0.8, iter=8000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=True
# [1252/1296] alpha=0.8, iter=8000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=True
# [1253/1296] alpha=0.8, iter=8000, neigh=insert, ihc_iter=4000, ihc_noimp=800, delta=True
# [1254/1296] alpha=0.8, iter=8000, neigh=insert, ihc_iter=4000, ihc_noimp=1500, delta=True
# [1255/1296] alpha=0.8, iter=8000, neigh=insert, ihc_iter=6000, ihc_noimp=400, delta=True
# [1256/1296] alpha=0.8, iter=8000, neigh=insert, ihc_iter=6000, ihc_noimp=800, delta=True
# [1257/1296] alpha=0.8, iter=8000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=True
# [1258/1296] alpha=0.8, iter=8000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=True
# [1259/1296] alpha=0.8, iter=8000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=True
# [1260/1296] alpha=0.8, iter=8000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=True
# [1261/1296] alpha=0.8, iter=8000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=True
# [1262/1296] alpha=0.8, iter=8000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=True
# [1263/1296] alpha=0.8, iter=8000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=True
# [1264/1296] alpha=0.8, iter=8000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=True
# [1265/1296] alpha=0.8, iter=8000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=True
# [1266/1296] alpha=0.8, iter=8000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=True
# [1267/1296] alpha=0.8, iter=8000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=True
# [1268/1296] alpha=0.8, iter=8000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=True
# [1269/1296] alpha=0.8, iter=8000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=True
# [1270/1296] alpha=0.8, iter=10000, neigh=swap, ihc_iter=4000, ihc_noimp=400, delta=True
# [1271/1296] alpha=0.8, iter=10000, neigh=swap, ihc_iter=4000, ihc_noimp=800, delta=True
# [1272/1296] alpha=0.8, iter=10000, neigh=swap, ihc_iter=4000, ihc_noimp=1500, delta=True
# [1273/1296] alpha=0.8, iter=10000, neigh=swap, ihc_iter=6000, ihc_noimp=400, delta=True
# [1274/1296] alpha=0.8, iter=10000, neigh=swap, ihc_iter=6000, ihc_noimp=800, delta=True
# [1275/1296] alpha=0.8, iter=10000, neigh=swap, ihc_iter=6000, ihc_noimp=1500, delta=True
# [1276/1296] alpha=0.8, iter=10000, neigh=swap, ihc_iter=8000, ihc_noimp=400, delta=True
# [1277/1296] alpha=0.8, iter=10000, neigh=swap, ihc_iter=8000, ihc_noimp=800, delta=True
# [1278/1296] alpha=0.8, iter=10000, neigh=swap, ihc_iter=8000, ihc_noimp=1500, delta=True
# [1279/1296] alpha=0.8, iter=10000, neigh=insert, ihc_iter=4000, ihc_noimp=400, delta=True
# [1280/1296] alpha=0.8, iter=10000, neigh=insert, ihc_iter=4000, ihc_noimp=800, delta=True
# [1281/1296] alpha=0.8, iter=10000, neigh=insert, ihc_iter=4000, ihc_noimp=1500, delta=True
# [1282/1296] alpha=0.8, iter=10000, neigh=insert, ihc_iter=6000, ihc_noimp=400, delta=True
# [1283/1296] alpha=0.8, iter=10000, neigh=insert, ihc_iter=6000, ihc_noimp=800, delta=True
# [1284/1296] alpha=0.8, iter=10000, neigh=insert, ihc_iter=6000, ihc_noimp=1500, delta=True
# [1285/1296] alpha=0.8, iter=10000, neigh=insert, ihc_iter=8000, ihc_noimp=400, delta=True
# [1286/1296] alpha=0.8, iter=10000, neigh=insert, ihc_iter=8000, ihc_noimp=800, delta=True
# [1287/1296] alpha=0.8, iter=10000, neigh=insert, ihc_iter=8000, ihc_noimp=1500, delta=True
# [1288/1296] alpha=0.8, iter=10000, neigh=two_opt, ihc_iter=4000, ihc_noimp=400, delta=True
# [1289/1296] alpha=0.8, iter=10000, neigh=two_opt, ihc_iter=4000, ihc_noimp=800, delta=True
# [1290/1296] alpha=0.8, iter=10000, neigh=two_opt, ihc_iter=4000, ihc_noimp=1500, delta=True
# [1291/1296] alpha=0.8, iter=10000, neigh=two_opt, ihc_iter=6000, ihc_noimp=400, delta=True
# [1292/1296] alpha=0.8, iter=10000, neigh=two_opt, ihc_iter=6000, ihc_noimp=800, delta=True
# [1293/1296] alpha=0.8, iter=10000, neigh=two_opt, ihc_iter=6000, ihc_noimp=1500, delta=True
# [1294/1296] alpha=0.8, iter=10000, neigh=two_opt, ihc_iter=8000, ihc_noimp=400, delta=True
# [1295/1296] alpha=0.8, iter=10000, neigh=two_opt, ihc_iter=8000, ihc_noimp=800, delta=True
# [1296/1296] alpha=0.8, iter=10000, neigh=two_opt, ihc_iter=8000, ihc_noimp=1500, delta=True
#
# Łączny czas eksperymentów: 593.90 min (35633.99 sek)
#
#
# Podsumowanie (pierwsze 20 wierszy):
#         instance  alpha  iterations neighborhood_type  ihc_max_iter  ihc_stop_no_improve  use_delta  mean_cost  mean_runtime  min_cost                                                                                                                                min_route
# Dane_TSP_48.xlsx    0.2       10000           two_opt          8000                 1500       True     9822.6     28.151774    9809.0 10-45-35-26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24
# Dane_TSP_48.xlsx    0.2       10000           two_opt          4000                 1500       True     9841.2     23.235155    9809.0 29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30-6-37-19-27-43-17-0-4-26-35-45-10-24-42-2
# Dane_TSP_48.xlsx    0.6        8000           two_opt          8000                 1500       True     9821.2     26.739156    9809.0 45-10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30-6-37-19-27-43-17-0-4-26-35
# Dane_TSP_48.xlsx    0.6       10000           two_opt          4000                 1500       True     9830.4     27.088793    9809.0 0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35-26-4
# Dane_TSP_48.xlsx    0.6       10000           two_opt          6000                 1500       True     9823.0     29.387497    9809.0 31-44-18-7-36-28-30-6-37-19-27-43-17-0-4-26-35-45-10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38
# Dane_TSP_48.xlsx    0.2        8000           two_opt          8000                 1500       True     9823.0     25.567112    9809.0 37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35-26-4-0-17-43-27-19
# Dane_TSP_48.xlsx    0.2        8000           two_opt          6000                 1500       True     9833.4     21.381499    9809.0 45-10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30-6-37-19-27-43-17-0-4-26-35
# Dane_TSP_48.xlsx    0.2        8000           two_opt          6000                  800       True     9839.8     18.712726    9809.0 18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35-26-4-0-17-43-27-19-37-6-30-28-36-7
# Dane_TSP_48.xlsx    0.2        8000           two_opt          6000                  400       True     9878.4     15.410088    9809.0 4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35-26
# Dane_TSP_48.xlsx    0.2        8000           two_opt          4000                  400       True     9903.4     19.257181    9809.0 35-26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45
# Dane_TSP_48.xlsx    0.2        8000            insert          6000                 1500       True     9946.4     23.821570    9809.0 29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30-6-37-19-27-43-17-0-4-26-35-45-10-24-42-2
# Dane_TSP_48.xlsx    0.6       10000           two_opt          8000                 1500       True     9821.0     33.630947    9809.0 26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35
# Dane_TSP_48.xlsx    0.8        3000           two_opt          4000                  800       True     9931.4      9.255832    9809.0 38-31-44-18-7-36-28-30-6-37-19-27-43-17-0-4-26-35-45-10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8
# Dane_TSP_48.xlsx    0.8        3000           two_opt          6000                  800       True     9873.0      8.169536    9809.0 3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30-6-37-19-27-43-17-0-4-26-35-45-10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22
# Dane_TSP_48.xlsx    0.8        3000           two_opt          6000                 1500       True     9828.4      9.883271    9809.0 35-45-10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30-6-37-19-27-43-17-0-4-26
# Dane_TSP_48.xlsx    0.8        3000           two_opt          8000                  800       True     9875.8      7.885168    9809.0 35-26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45
# Dane_TSP_48.xlsx    0.2       10000           two_opt          6000                  800       True     9851.2     25.045034    9809.0 0-4-26-35-45-10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30-6-37-19-27-43-17
# Dane_TSP_48.xlsx    0.8        3000           two_opt          8000                 1500       True     9847.8      9.178882    9809.0 43-17-0-4-26-35-45-10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30-6-37-19-27
# Dane_TSP_48.xlsx    0.2       10000           two_opt          8000                  800       True     9833.4     23.525011    9809.0 27-43-17-0-4-26-35-45-10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30-6-37-19
# Dane_TSP_48.xlsx    0.6        8000           two_opt          6000                 1500       True     9825.6     25.009970    9809.0 26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35
#
# Najlepsze parametry dla każdej instancji:
#
# Dane_TSP_48.xlsx
# odległość 9809.0 = {'instance': 'Dane_TSP_48.xlsx', 'alpha': 0.4, 'iterations': 10000, 'neighborhood_type': 'two_opt', 'ihc_max_iter': 8000, 'ihc_stop_no_improve': 1500, 'use_delta': True, 'mean_cost': 9814.4, 'mean_runtime': 29.05558681488037, 'min_cost': 9809.0, 'min_route': '17-0-4-26-35-45-10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30-6-37-19-27-43'}
#
# Dane_TSP_76.xlsx
# odległość 99069.816 = {'instance': 'Dane_TSP_76.xlsx', 'alpha': 0.6, 'iterations': 8000, 'neighborhood_type': 'two_opt', 'ihc_max_iter': 8000, 'ihc_stop_no_improve': 1500, 'use_delta': True, 'mean_cost': 100073.986, 'mean_runtime': 36.98775753974915, 'min_cost': 99069.816, 'min_route': '2-8-7-6-3-4-5-20-19-31-30-29-26-27-28-43-42-54-53-52-49-50-51-66-65-71-72-73-64-63-57-56-55-58-61-62-59-60-41-40-34-33-32-35-39-38-36-37-18-17-16-15-11-10-9-12-13-14-74-0-70-67-68-69-47-48-44-45-46-24-25-21-22-23-1-75-76'}
#
# Dane_TSP_127.xlsx
# odległość 127612.694 = {'instance': 'Dane_TSP_127.xlsx', 'alpha': 0.2, 'iterations': 5000, 'neighborhood_type': 'two_opt', 'ihc_max_iter': 8000, 'ihc_stop_no_improve': 800, 'use_delta': True, 'mean_cost': 129905.396, 'mean_runtime': 30.721813201904297, 'min_cost': 127612.694, 'min_route': '0-101-102-63-119-96-88-85-86-87-109-110-71-70-68-74-73-67-9-11-108-24-23-4-22-19-8-72-18-21-17-20-15-106-6-114-7-105-1-16-14-12-41-37-36-80-79-77-76-69-75-81-117-78-84-82-83-126-32-29-122-33-25-28-42-39-38-26-27-31-30-43-34-40-103-45-44-54-57-51-35-2-50-52-124-56-5-121-115-13-120-10-3-90-91-61-62-58-100-64-113-65-99-92-89-125-104-59-60-116-66-55-47-46-49-53-118-48-94-112-111-107-127-93-95-123-97-98'}
