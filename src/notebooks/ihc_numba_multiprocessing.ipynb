# %%
# SKRYPT EKSPERYMENTALNY
# Uruchamia serię eksperymentów z różnymi parametrami algorytmu,
# zapisuje statystyki dla każdej kombinacji oraz mierzy pełny
# czas działania. Dane wynikowe trafiają do pliku CSV.
#
# Główne elementy:
#   - rozgrzanie kompilatora Numba (aby uniknąć narzutu JIT)
#   - wielokrotne uruchamianie algorytmu z tymi samymi parametrami
#   - multiprocessing (każde powtórzenie w osobnym procesie)
#   - wyznaczanie średnich kosztów i czasów
#   - zapisywanie najlepszej (minimalnej) trasy
#   - zapis wyników przy użyciu save_experiment_results()

# %load_ext autoreload
# %autoreload 2

import time
import pandas as pd
import numpy as np
import itertools
from multiprocessing import Pool, cpu_count

from src.utils.tsp_loader import load_tsp_matrix
from src.algorithms.ihc_numba import solve_tsp
from src.utils.result_saver import save_experiment_results
from src.utils.run_single_repeat import run_single_repeat

# USTAWIENIA
TSP_FILES = ["Dane_TSP_48.xlsx", "Dane_TSP_76.xlsx", "Dane_TSP_127.xlsx"]

PARAM_GRID = {
    "n_starts": [500, 1_000, 5_000, 10_000], # liczba restartów wspinaczki
    "max_iter": [1_000, 5_000, 50_000, 200_000], # liczba iteracji jednej wspinaczki
    "stop_no_improve": [500, 1_000, 3_000, 10_000],  # limit stagnacji
    "neighborhood_type": ["swap", "insert", "two_opt"],
}
# TSP_FILES = ["Dane_TSP_76.xlsx"]
# PARAM_GRID = {
#     "n_starts": [5_000], # liczba restartów wspinaczki
#     "max_iter": [25_000], # liczba iteracji jednej wspinaczki
#     "stop_no_improve": [500],  # limit stagnacji
#     "neighborhood_type": ["swap"],
# }

REPEATS = 5   # liczba powtórzeń dla każdej kombinacji parametrów
results = []  # tablica na wyniki


# ROZGRZANIE NUMBA (KOMPILACJA JIT)
print("Rozgrzewanie Numba (kompilacja JIT)...")
D = load_tsp_matrix(TSP_FILES[0])
_ = solve_tsp(D, {"n_starts": 2})
print("Kompilacja zakończona.\n")


# GŁÓWNA PĘTLA
# Obliczamy łączną liczbę kombinacji
all_combos = list(itertools.product(
    PARAM_GRID["n_starts"],
    PARAM_GRID["max_iter"],
    PARAM_GRID["stop_no_improve"],
    PARAM_GRID["neighborhood_type"]
))
total = len(all_combos) * len(TSP_FILES)
counter = 0

start_total = time.perf_counter()

for tsp_file in TSP_FILES:
    print(f"\nInstancja: {tsp_file}")
    D = load_tsp_matrix(tsp_file)

    for n_starts in PARAM_GRID["n_starts"]:
        for max_iter in PARAM_GRID["max_iter"]:
            for stop_no_improve in PARAM_GRID["stop_no_improve"]:
                for neighborhood_type in PARAM_GRID["neighborhood_type"]:
                    counter += 1

                    print(
                        f"[{counter}/{total}] "
                        f"n_starts={n_starts}, "
                        f"max_iter={max_iter}, "
                        f"stop_no_improve={stop_no_improve}, "
                        f"neigh={neighborhood_type}"
                    )

                    params = {
                        "n_starts": n_starts,
                        "max_iter": max_iter,
                        "stop_no_improve": stop_no_improve,
                        "neighborhood_type": neighborhood_type,
                        "use_delta": True
                    }

                    # multiprocessing — równoległe powtórzenia
                    with Pool(processes=cpu_count()) as pool:
                        parallel_jobs = [
                            (solve_tsp, D, params) for _ in range(REPEATS)
                        ]

                        results_parallel = pool.map(run_single_repeat, parallel_jobs)

                    costs = [c for c, _, _ in results_parallel]
                    routes = [r for _, r, _ in results_parallel]
                    runtimes = [t for _, _, t in results_parallel]

                    # wybór najlepszej trasy
                    min_cost = min(costs)
                    best_route_overall = routes[costs.index(min_cost)]
                    route_str = "-".join(map(str, best_route_overall))

                    # zapis danych
                    results.append({
                        "instance": tsp_file,
                        "n_starts": n_starts,
                        "max_iter": max_iter,
                        "stop_no_improve": stop_no_improve,
                        "neighborhood_type": neighborhood_type,
                        "mean_cost": round(np.mean(costs), 3),
                        "mean_runtime": np.mean(runtimes),
                        "min_cost": round(min_cost, 3),
                        "min_route": route_str,
                    })


# PODSUMOWANIE I ZAPIS WYNIKÓW
end_total = time.perf_counter()
elapsed = end_total - start_total

print(f"\nŁączny czas eksperymentów: {elapsed/60:.2f} min ({elapsed:.2f} sek)")

df = pd.DataFrame(results)
save_experiment_results(df, filename="with_delta__results.csv", time_seconds=int(elapsed), subfolder="IHC")


# RAPORT
print("\nNajlepsze parametry dla każdej instancji:")

instances = df["instance"].unique()

for inst in instances:
    sub = df[df["instance"] == inst]
    best_row = sub.loc[sub["mean_cost"].idxmin()]
    print(f"\n{inst}")
    # print(best_row["min_cost"], best_row.to_dict())
    print(f"odległość {best_row["min_cost"]} = {best_row.to_dict()}")
# Out:
# Rozgrzewanie Numba (kompilacja JIT)...
# Kompilacja zakończona.
#
#
# Instancja: Dane_TSP_48.xlsx
# [1/576] n_starts=500, max_iter=1000, stop_no_improve=500, neigh=swap
# [2/576] n_starts=500, max_iter=1000, stop_no_improve=500, neigh=insert
# [3/576] n_starts=500, max_iter=1000, stop_no_improve=500, neigh=two_opt
# [4/576] n_starts=500, max_iter=1000, stop_no_improve=1000, neigh=swap
# [5/576] n_starts=500, max_iter=1000, stop_no_improve=1000, neigh=insert
# [6/576] n_starts=500, max_iter=1000, stop_no_improve=1000, neigh=two_opt
# [7/576] n_starts=500, max_iter=1000, stop_no_improve=3000, neigh=swap
# [8/576] n_starts=500, max_iter=1000, stop_no_improve=3000, neigh=insert
# [9/576] n_starts=500, max_iter=1000, stop_no_improve=3000, neigh=two_opt
# [10/576] n_starts=500, max_iter=1000, stop_no_improve=10000, neigh=swap
# [11/576] n_starts=500, max_iter=1000, stop_no_improve=10000, neigh=insert
# [12/576] n_starts=500, max_iter=1000, stop_no_improve=10000, neigh=two_opt
# [13/576] n_starts=500, max_iter=5000, stop_no_improve=500, neigh=swap
# [14/576] n_starts=500, max_iter=5000, stop_no_improve=500, neigh=insert
# [15/576] n_starts=500, max_iter=5000, stop_no_improve=500, neigh=two_opt
# [16/576] n_starts=500, max_iter=5000, stop_no_improve=1000, neigh=swap
# [17/576] n_starts=500, max_iter=5000, stop_no_improve=1000, neigh=insert
# [18/576] n_starts=500, max_iter=5000, stop_no_improve=1000, neigh=two_opt
# [19/576] n_starts=500, max_iter=5000, stop_no_improve=3000, neigh=swap
# [20/576] n_starts=500, max_iter=5000, stop_no_improve=3000, neigh=insert
# [21/576] n_starts=500, max_iter=5000, stop_no_improve=3000, neigh=two_opt
# [22/576] n_starts=500, max_iter=5000, stop_no_improve=10000, neigh=swap
# [23/576] n_starts=500, max_iter=5000, stop_no_improve=10000, neigh=insert
# [24/576] n_starts=500, max_iter=5000, stop_no_improve=10000, neigh=two_opt
# [25/576] n_starts=500, max_iter=50000, stop_no_improve=500, neigh=swap
# [26/576] n_starts=500, max_iter=50000, stop_no_improve=500, neigh=insert
# [27/576] n_starts=500, max_iter=50000, stop_no_improve=500, neigh=two_opt
# [28/576] n_starts=500, max_iter=50000, stop_no_improve=1000, neigh=swap
# [29/576] n_starts=500, max_iter=50000, stop_no_improve=1000, neigh=insert
# [30/576] n_starts=500, max_iter=50000, stop_no_improve=1000, neigh=two_opt
# [31/576] n_starts=500, max_iter=50000, stop_no_improve=3000, neigh=swap
# [32/576] n_starts=500, max_iter=50000, stop_no_improve=3000, neigh=insert
# [33/576] n_starts=500, max_iter=50000, stop_no_improve=3000, neigh=two_opt
# [34/576] n_starts=500, max_iter=50000, stop_no_improve=10000, neigh=swap
# [35/576] n_starts=500, max_iter=50000, stop_no_improve=10000, neigh=insert
# [36/576] n_starts=500, max_iter=50000, stop_no_improve=10000, neigh=two_opt
# [37/576] n_starts=500, max_iter=200000, stop_no_improve=500, neigh=swap
# [38/576] n_starts=500, max_iter=200000, stop_no_improve=500, neigh=insert
# [39/576] n_starts=500, max_iter=200000, stop_no_improve=500, neigh=two_opt
# [40/576] n_starts=500, max_iter=200000, stop_no_improve=1000, neigh=swap
# [41/576] n_starts=500, max_iter=200000, stop_no_improve=1000, neigh=insert
# [42/576] n_starts=500, max_iter=200000, stop_no_improve=1000, neigh=two_opt
# [43/576] n_starts=500, max_iter=200000, stop_no_improve=3000, neigh=swap
# [44/576] n_starts=500, max_iter=200000, stop_no_improve=3000, neigh=insert
# [45/576] n_starts=500, max_iter=200000, stop_no_improve=3000, neigh=two_opt
# [46/576] n_starts=500, max_iter=200000, stop_no_improve=10000, neigh=swap
# [47/576] n_starts=500, max_iter=200000, stop_no_improve=10000, neigh=insert
# [48/576] n_starts=500, max_iter=200000, stop_no_improve=10000, neigh=two_opt
# [49/576] n_starts=1000, max_iter=1000, stop_no_improve=500, neigh=swap
# [50/576] n_starts=1000, max_iter=1000, stop_no_improve=500, neigh=insert
# [51/576] n_starts=1000, max_iter=1000, stop_no_improve=500, neigh=two_opt
# [52/576] n_starts=1000, max_iter=1000, stop_no_improve=1000, neigh=swap
# [53/576] n_starts=1000, max_iter=1000, stop_no_improve=1000, neigh=insert
# [54/576] n_starts=1000, max_iter=1000, stop_no_improve=1000, neigh=two_opt
# [55/576] n_starts=1000, max_iter=1000, stop_no_improve=3000, neigh=swap
# [56/576] n_starts=1000, max_iter=1000, stop_no_improve=3000, neigh=insert
# [57/576] n_starts=1000, max_iter=1000, stop_no_improve=3000, neigh=two_opt
# [58/576] n_starts=1000, max_iter=1000, stop_no_improve=10000, neigh=swap
# [59/576] n_starts=1000, max_iter=1000, stop_no_improve=10000, neigh=insert
# [60/576] n_starts=1000, max_iter=1000, stop_no_improve=10000, neigh=two_opt
# [61/576] n_starts=1000, max_iter=5000, stop_no_improve=500, neigh=swap
# [62/576] n_starts=1000, max_iter=5000, stop_no_improve=500, neigh=insert
# [63/576] n_starts=1000, max_iter=5000, stop_no_improve=500, neigh=two_opt
# [64/576] n_starts=1000, max_iter=5000, stop_no_improve=1000, neigh=swap
# [65/576] n_starts=1000, max_iter=5000, stop_no_improve=1000, neigh=insert
# [66/576] n_starts=1000, max_iter=5000, stop_no_improve=1000, neigh=two_opt
# [67/576] n_starts=1000, max_iter=5000, stop_no_improve=3000, neigh=swap
# [68/576] n_starts=1000, max_iter=5000, stop_no_improve=3000, neigh=insert
# [69/576] n_starts=1000, max_iter=5000, stop_no_improve=3000, neigh=two_opt
# [70/576] n_starts=1000, max_iter=5000, stop_no_improve=10000, neigh=swap
# [71/576] n_starts=1000, max_iter=5000, stop_no_improve=10000, neigh=insert
# [72/576] n_starts=1000, max_iter=5000, stop_no_improve=10000, neigh=two_opt
# [73/576] n_starts=1000, max_iter=50000, stop_no_improve=500, neigh=swap
# [74/576] n_starts=1000, max_iter=50000, stop_no_improve=500, neigh=insert
# [75/576] n_starts=1000, max_iter=50000, stop_no_improve=500, neigh=two_opt
# [76/576] n_starts=1000, max_iter=50000, stop_no_improve=1000, neigh=swap
# [77/576] n_starts=1000, max_iter=50000, stop_no_improve=1000, neigh=insert
# [78/576] n_starts=1000, max_iter=50000, stop_no_improve=1000, neigh=two_opt
# [79/576] n_starts=1000, max_iter=50000, stop_no_improve=3000, neigh=swap
# [80/576] n_starts=1000, max_iter=50000, stop_no_improve=3000, neigh=insert
# [81/576] n_starts=1000, max_iter=50000, stop_no_improve=3000, neigh=two_opt
# [82/576] n_starts=1000, max_iter=50000, stop_no_improve=10000, neigh=swap
# [83/576] n_starts=1000, max_iter=50000, stop_no_improve=10000, neigh=insert
# [84/576] n_starts=1000, max_iter=50000, stop_no_improve=10000, neigh=two_opt
# [85/576] n_starts=1000, max_iter=200000, stop_no_improve=500, neigh=swap
# [86/576] n_starts=1000, max_iter=200000, stop_no_improve=500, neigh=insert
# [87/576] n_starts=1000, max_iter=200000, stop_no_improve=500, neigh=two_opt
# [88/576] n_starts=1000, max_iter=200000, stop_no_improve=1000, neigh=swap
# [89/576] n_starts=1000, max_iter=200000, stop_no_improve=1000, neigh=insert
# [90/576] n_starts=1000, max_iter=200000, stop_no_improve=1000, neigh=two_opt
# [91/576] n_starts=1000, max_iter=200000, stop_no_improve=3000, neigh=swap
# [92/576] n_starts=1000, max_iter=200000, stop_no_improve=3000, neigh=insert
# [93/576] n_starts=1000, max_iter=200000, stop_no_improve=3000, neigh=two_opt
# [94/576] n_starts=1000, max_iter=200000, stop_no_improve=10000, neigh=swap
# [95/576] n_starts=1000, max_iter=200000, stop_no_improve=10000, neigh=insert
# [96/576] n_starts=1000, max_iter=200000, stop_no_improve=10000, neigh=two_opt
# [97/576] n_starts=5000, max_iter=1000, stop_no_improve=500, neigh=swap
# [98/576] n_starts=5000, max_iter=1000, stop_no_improve=500, neigh=insert
# [99/576] n_starts=5000, max_iter=1000, stop_no_improve=500, neigh=two_opt
# [100/576] n_starts=5000, max_iter=1000, stop_no_improve=1000, neigh=swap
# [101/576] n_starts=5000, max_iter=1000, stop_no_improve=1000, neigh=insert
# [102/576] n_starts=5000, max_iter=1000, stop_no_improve=1000, neigh=two_opt
# [103/576] n_starts=5000, max_iter=1000, stop_no_improve=3000, neigh=swap
# [104/576] n_starts=5000, max_iter=1000, stop_no_improve=3000, neigh=insert
# [105/576] n_starts=5000, max_iter=1000, stop_no_improve=3000, neigh=two_opt
# [106/576] n_starts=5000, max_iter=1000, stop_no_improve=10000, neigh=swap
# [107/576] n_starts=5000, max_iter=1000, stop_no_improve=10000, neigh=insert
# [108/576] n_starts=5000, max_iter=1000, stop_no_improve=10000, neigh=two_opt
# [109/576] n_starts=5000, max_iter=5000, stop_no_improve=500, neigh=swap
# [110/576] n_starts=5000, max_iter=5000, stop_no_improve=500, neigh=insert
# [111/576] n_starts=5000, max_iter=5000, stop_no_improve=500, neigh=two_opt
# [112/576] n_starts=5000, max_iter=5000, stop_no_improve=1000, neigh=swap
# [113/576] n_starts=5000, max_iter=5000, stop_no_improve=1000, neigh=insert
# [114/576] n_starts=5000, max_iter=5000, stop_no_improve=1000, neigh=two_opt
# [115/576] n_starts=5000, max_iter=5000, stop_no_improve=3000, neigh=swap
# [116/576] n_starts=5000, max_iter=5000, stop_no_improve=3000, neigh=insert
# [117/576] n_starts=5000, max_iter=5000, stop_no_improve=3000, neigh=two_opt
# [118/576] n_starts=5000, max_iter=5000, stop_no_improve=10000, neigh=swap
# [119/576] n_starts=5000, max_iter=5000, stop_no_improve=10000, neigh=insert
# [120/576] n_starts=5000, max_iter=5000, stop_no_improve=10000, neigh=two_opt
# [121/576] n_starts=5000, max_iter=50000, stop_no_improve=500, neigh=swap
# [122/576] n_starts=5000, max_iter=50000, stop_no_improve=500, neigh=insert
# [123/576] n_starts=5000, max_iter=50000, stop_no_improve=500, neigh=two_opt
# [124/576] n_starts=5000, max_iter=50000, stop_no_improve=1000, neigh=swap
# [125/576] n_starts=5000, max_iter=50000, stop_no_improve=1000, neigh=insert
# [126/576] n_starts=5000, max_iter=50000, stop_no_improve=1000, neigh=two_opt
# [127/576] n_starts=5000, max_iter=50000, stop_no_improve=3000, neigh=swap
# [128/576] n_starts=5000, max_iter=50000, stop_no_improve=3000, neigh=insert
# [129/576] n_starts=5000, max_iter=50000, stop_no_improve=3000, neigh=two_opt
# [130/576] n_starts=5000, max_iter=50000, stop_no_improve=10000, neigh=swap
# [131/576] n_starts=5000, max_iter=50000, stop_no_improve=10000, neigh=insert
# [132/576] n_starts=5000, max_iter=50000, stop_no_improve=10000, neigh=two_opt
# [133/576] n_starts=5000, max_iter=200000, stop_no_improve=500, neigh=swap
# [134/576] n_starts=5000, max_iter=200000, stop_no_improve=500, neigh=insert
# [135/576] n_starts=5000, max_iter=200000, stop_no_improve=500, neigh=two_opt
# [136/576] n_starts=5000, max_iter=200000, stop_no_improve=1000, neigh=swap
# [137/576] n_starts=5000, max_iter=200000, stop_no_improve=1000, neigh=insert
# [138/576] n_starts=5000, max_iter=200000, stop_no_improve=1000, neigh=two_opt
# [139/576] n_starts=5000, max_iter=200000, stop_no_improve=3000, neigh=swap
# [140/576] n_starts=5000, max_iter=200000, stop_no_improve=3000, neigh=insert
# [141/576] n_starts=5000, max_iter=200000, stop_no_improve=3000, neigh=two_opt
# [142/576] n_starts=5000, max_iter=200000, stop_no_improve=10000, neigh=swap
# [143/576] n_starts=5000, max_iter=200000, stop_no_improve=10000, neigh=insert
# [144/576] n_starts=5000, max_iter=200000, stop_no_improve=10000, neigh=two_opt
# [145/576] n_starts=10000, max_iter=1000, stop_no_improve=500, neigh=swap
# [146/576] n_starts=10000, max_iter=1000, stop_no_improve=500, neigh=insert
# [147/576] n_starts=10000, max_iter=1000, stop_no_improve=500, neigh=two_opt
# [148/576] n_starts=10000, max_iter=1000, stop_no_improve=1000, neigh=swap
# [149/576] n_starts=10000, max_iter=1000, stop_no_improve=1000, neigh=insert
# [150/576] n_starts=10000, max_iter=1000, stop_no_improve=1000, neigh=two_opt
# [151/576] n_starts=10000, max_iter=1000, stop_no_improve=3000, neigh=swap
# [152/576] n_starts=10000, max_iter=1000, stop_no_improve=3000, neigh=insert
# [153/576] n_starts=10000, max_iter=1000, stop_no_improve=3000, neigh=two_opt
# [154/576] n_starts=10000, max_iter=1000, stop_no_improve=10000, neigh=swap
# [155/576] n_starts=10000, max_iter=1000, stop_no_improve=10000, neigh=insert
# [156/576] n_starts=10000, max_iter=1000, stop_no_improve=10000, neigh=two_opt
# [157/576] n_starts=10000, max_iter=5000, stop_no_improve=500, neigh=swap
# [158/576] n_starts=10000, max_iter=5000, stop_no_improve=500, neigh=insert
# [159/576] n_starts=10000, max_iter=5000, stop_no_improve=500, neigh=two_opt
# [160/576] n_starts=10000, max_iter=5000, stop_no_improve=1000, neigh=swap
# [161/576] n_starts=10000, max_iter=5000, stop_no_improve=1000, neigh=insert
# [162/576] n_starts=10000, max_iter=5000, stop_no_improve=1000, neigh=two_opt
# [163/576] n_starts=10000, max_iter=5000, stop_no_improve=3000, neigh=swap
# [164/576] n_starts=10000, max_iter=5000, stop_no_improve=3000, neigh=insert
# [165/576] n_starts=10000, max_iter=5000, stop_no_improve=3000, neigh=two_opt
# [166/576] n_starts=10000, max_iter=5000, stop_no_improve=10000, neigh=swap
# [167/576] n_starts=10000, max_iter=5000, stop_no_improve=10000, neigh=insert
# [168/576] n_starts=10000, max_iter=5000, stop_no_improve=10000, neigh=two_opt
# [169/576] n_starts=10000, max_iter=50000, stop_no_improve=500, neigh=swap
# [170/576] n_starts=10000, max_iter=50000, stop_no_improve=500, neigh=insert
# [171/576] n_starts=10000, max_iter=50000, stop_no_improve=500, neigh=two_opt
# [172/576] n_starts=10000, max_iter=50000, stop_no_improve=1000, neigh=swap
# [173/576] n_starts=10000, max_iter=50000, stop_no_improve=1000, neigh=insert
# [174/576] n_starts=10000, max_iter=50000, stop_no_improve=1000, neigh=two_opt
# [175/576] n_starts=10000, max_iter=50000, stop_no_improve=3000, neigh=swap
# [176/576] n_starts=10000, max_iter=50000, stop_no_improve=3000, neigh=insert
# [177/576] n_starts=10000, max_iter=50000, stop_no_improve=3000, neigh=two_opt
# [178/576] n_starts=10000, max_iter=50000, stop_no_improve=10000, neigh=swap
# [179/576] n_starts=10000, max_iter=50000, stop_no_improve=10000, neigh=insert
# [180/576] n_starts=10000, max_iter=50000, stop_no_improve=10000, neigh=two_opt
# [181/576] n_starts=10000, max_iter=200000, stop_no_improve=500, neigh=swap
# [182/576] n_starts=10000, max_iter=200000, stop_no_improve=500, neigh=insert
# [183/576] n_starts=10000, max_iter=200000, stop_no_improve=500, neigh=two_opt
# [184/576] n_starts=10000, max_iter=200000, stop_no_improve=1000, neigh=swap
# [185/576] n_starts=10000, max_iter=200000, stop_no_improve=1000, neigh=insert
# [186/576] n_starts=10000, max_iter=200000, stop_no_improve=1000, neigh=two_opt
# [187/576] n_starts=10000, max_iter=200000, stop_no_improve=3000, neigh=swap
# [188/576] n_starts=10000, max_iter=200000, stop_no_improve=3000, neigh=insert
# [189/576] n_starts=10000, max_iter=200000, stop_no_improve=3000, neigh=two_opt
# [190/576] n_starts=10000, max_iter=200000, stop_no_improve=10000, neigh=swap
# [191/576] n_starts=10000, max_iter=200000, stop_no_improve=10000, neigh=insert
# [192/576] n_starts=10000, max_iter=200000, stop_no_improve=10000, neigh=two_opt
#
# Instancja: Dane_TSP_76.xlsx
# [193/576] n_starts=500, max_iter=1000, stop_no_improve=500, neigh=swap
# [194/576] n_starts=500, max_iter=1000, stop_no_improve=500, neigh=insert
# [195/576] n_starts=500, max_iter=1000, stop_no_improve=500, neigh=two_opt
# [196/576] n_starts=500, max_iter=1000, stop_no_improve=1000, neigh=swap
# [197/576] n_starts=500, max_iter=1000, stop_no_improve=1000, neigh=insert
# [198/576] n_starts=500, max_iter=1000, stop_no_improve=1000, neigh=two_opt
# [199/576] n_starts=500, max_iter=1000, stop_no_improve=3000, neigh=swap
# [200/576] n_starts=500, max_iter=1000, stop_no_improve=3000, neigh=insert
# [201/576] n_starts=500, max_iter=1000, stop_no_improve=3000, neigh=two_opt
# [202/576] n_starts=500, max_iter=1000, stop_no_improve=10000, neigh=swap
# [203/576] n_starts=500, max_iter=1000, stop_no_improve=10000, neigh=insert
# [204/576] n_starts=500, max_iter=1000, stop_no_improve=10000, neigh=two_opt
# [205/576] n_starts=500, max_iter=5000, stop_no_improve=500, neigh=swap
# [206/576] n_starts=500, max_iter=5000, stop_no_improve=500, neigh=insert
# [207/576] n_starts=500, max_iter=5000, stop_no_improve=500, neigh=two_opt
# [208/576] n_starts=500, max_iter=5000, stop_no_improve=1000, neigh=swap
# [209/576] n_starts=500, max_iter=5000, stop_no_improve=1000, neigh=insert
# [210/576] n_starts=500, max_iter=5000, stop_no_improve=1000, neigh=two_opt
# [211/576] n_starts=500, max_iter=5000, stop_no_improve=3000, neigh=swap
# [212/576] n_starts=500, max_iter=5000, stop_no_improve=3000, neigh=insert
# [213/576] n_starts=500, max_iter=5000, stop_no_improve=3000, neigh=two_opt
# [214/576] n_starts=500, max_iter=5000, stop_no_improve=10000, neigh=swap
# [215/576] n_starts=500, max_iter=5000, stop_no_improve=10000, neigh=insert
# [216/576] n_starts=500, max_iter=5000, stop_no_improve=10000, neigh=two_opt
# [217/576] n_starts=500, max_iter=50000, stop_no_improve=500, neigh=swap
# [218/576] n_starts=500, max_iter=50000, stop_no_improve=500, neigh=insert
# [219/576] n_starts=500, max_iter=50000, stop_no_improve=500, neigh=two_opt
# [220/576] n_starts=500, max_iter=50000, stop_no_improve=1000, neigh=swap
# [221/576] n_starts=500, max_iter=50000, stop_no_improve=1000, neigh=insert
# [222/576] n_starts=500, max_iter=50000, stop_no_improve=1000, neigh=two_opt
# [223/576] n_starts=500, max_iter=50000, stop_no_improve=3000, neigh=swap
# [224/576] n_starts=500, max_iter=50000, stop_no_improve=3000, neigh=insert
# [225/576] n_starts=500, max_iter=50000, stop_no_improve=3000, neigh=two_opt
# [226/576] n_starts=500, max_iter=50000, stop_no_improve=10000, neigh=swap
# [227/576] n_starts=500, max_iter=50000, stop_no_improve=10000, neigh=insert
# [228/576] n_starts=500, max_iter=50000, stop_no_improve=10000, neigh=two_opt
# [229/576] n_starts=500, max_iter=200000, stop_no_improve=500, neigh=swap
# [230/576] n_starts=500, max_iter=200000, stop_no_improve=500, neigh=insert
# [231/576] n_starts=500, max_iter=200000, stop_no_improve=500, neigh=two_opt
# [232/576] n_starts=500, max_iter=200000, stop_no_improve=1000, neigh=swap
# [233/576] n_starts=500, max_iter=200000, stop_no_improve=1000, neigh=insert
# [234/576] n_starts=500, max_iter=200000, stop_no_improve=1000, neigh=two_opt
# [235/576] n_starts=500, max_iter=200000, stop_no_improve=3000, neigh=swap
# [236/576] n_starts=500, max_iter=200000, stop_no_improve=3000, neigh=insert
# [237/576] n_starts=500, max_iter=200000, stop_no_improve=3000, neigh=two_opt
# [238/576] n_starts=500, max_iter=200000, stop_no_improve=10000, neigh=swap
# [239/576] n_starts=500, max_iter=200000, stop_no_improve=10000, neigh=insert
# [240/576] n_starts=500, max_iter=200000, stop_no_improve=10000, neigh=two_opt
# [241/576] n_starts=1000, max_iter=1000, stop_no_improve=500, neigh=swap
# [242/576] n_starts=1000, max_iter=1000, stop_no_improve=500, neigh=insert
# [243/576] n_starts=1000, max_iter=1000, stop_no_improve=500, neigh=two_opt
# [244/576] n_starts=1000, max_iter=1000, stop_no_improve=1000, neigh=swap
# [245/576] n_starts=1000, max_iter=1000, stop_no_improve=1000, neigh=insert
# [246/576] n_starts=1000, max_iter=1000, stop_no_improve=1000, neigh=two_opt
# [247/576] n_starts=1000, max_iter=1000, stop_no_improve=3000, neigh=swap
# [248/576] n_starts=1000, max_iter=1000, stop_no_improve=3000, neigh=insert
# [249/576] n_starts=1000, max_iter=1000, stop_no_improve=3000, neigh=two_opt
# [250/576] n_starts=1000, max_iter=1000, stop_no_improve=10000, neigh=swap
# [251/576] n_starts=1000, max_iter=1000, stop_no_improve=10000, neigh=insert
# [252/576] n_starts=1000, max_iter=1000, stop_no_improve=10000, neigh=two_opt
# [253/576] n_starts=1000, max_iter=5000, stop_no_improve=500, neigh=swap
# [254/576] n_starts=1000, max_iter=5000, stop_no_improve=500, neigh=insert
# [255/576] n_starts=1000, max_iter=5000, stop_no_improve=500, neigh=two_opt
# [256/576] n_starts=1000, max_iter=5000, stop_no_improve=1000, neigh=swap
# [257/576] n_starts=1000, max_iter=5000, stop_no_improve=1000, neigh=insert
# [258/576] n_starts=1000, max_iter=5000, stop_no_improve=1000, neigh=two_opt
# [259/576] n_starts=1000, max_iter=5000, stop_no_improve=3000, neigh=swap
# [260/576] n_starts=1000, max_iter=5000, stop_no_improve=3000, neigh=insert
# [261/576] n_starts=1000, max_iter=5000, stop_no_improve=3000, neigh=two_opt
# [262/576] n_starts=1000, max_iter=5000, stop_no_improve=10000, neigh=swap
# [263/576] n_starts=1000, max_iter=5000, stop_no_improve=10000, neigh=insert
# [264/576] n_starts=1000, max_iter=5000, stop_no_improve=10000, neigh=two_opt
# [265/576] n_starts=1000, max_iter=50000, stop_no_improve=500, neigh=swap
# [266/576] n_starts=1000, max_iter=50000, stop_no_improve=500, neigh=insert
# [267/576] n_starts=1000, max_iter=50000, stop_no_improve=500, neigh=two_opt
# [268/576] n_starts=1000, max_iter=50000, stop_no_improve=1000, neigh=swap
# [269/576] n_starts=1000, max_iter=50000, stop_no_improve=1000, neigh=insert
# [270/576] n_starts=1000, max_iter=50000, stop_no_improve=1000, neigh=two_opt
# [271/576] n_starts=1000, max_iter=50000, stop_no_improve=3000, neigh=swap
# [272/576] n_starts=1000, max_iter=50000, stop_no_improve=3000, neigh=insert
# [273/576] n_starts=1000, max_iter=50000, stop_no_improve=3000, neigh=two_opt
# [274/576] n_starts=1000, max_iter=50000, stop_no_improve=10000, neigh=swap
# [275/576] n_starts=1000, max_iter=50000, stop_no_improve=10000, neigh=insert
# [276/576] n_starts=1000, max_iter=50000, stop_no_improve=10000, neigh=two_opt
# [277/576] n_starts=1000, max_iter=200000, stop_no_improve=500, neigh=swap
# [278/576] n_starts=1000, max_iter=200000, stop_no_improve=500, neigh=insert
# [279/576] n_starts=1000, max_iter=200000, stop_no_improve=500, neigh=two_opt
# [280/576] n_starts=1000, max_iter=200000, stop_no_improve=1000, neigh=swap
# [281/576] n_starts=1000, max_iter=200000, stop_no_improve=1000, neigh=insert
# [282/576] n_starts=1000, max_iter=200000, stop_no_improve=1000, neigh=two_opt
# [283/576] n_starts=1000, max_iter=200000, stop_no_improve=3000, neigh=swap
# [284/576] n_starts=1000, max_iter=200000, stop_no_improve=3000, neigh=insert
# [285/576] n_starts=1000, max_iter=200000, stop_no_improve=3000, neigh=two_opt
# [286/576] n_starts=1000, max_iter=200000, stop_no_improve=10000, neigh=swap
# [287/576] n_starts=1000, max_iter=200000, stop_no_improve=10000, neigh=insert
# [288/576] n_starts=1000, max_iter=200000, stop_no_improve=10000, neigh=two_opt
# [289/576] n_starts=5000, max_iter=1000, stop_no_improve=500, neigh=swap
# [290/576] n_starts=5000, max_iter=1000, stop_no_improve=500, neigh=insert
# [291/576] n_starts=5000, max_iter=1000, stop_no_improve=500, neigh=two_opt
# [292/576] n_starts=5000, max_iter=1000, stop_no_improve=1000, neigh=swap
# [293/576] n_starts=5000, max_iter=1000, stop_no_improve=1000, neigh=insert
# [294/576] n_starts=5000, max_iter=1000, stop_no_improve=1000, neigh=two_opt
# [295/576] n_starts=5000, max_iter=1000, stop_no_improve=3000, neigh=swap
# [296/576] n_starts=5000, max_iter=1000, stop_no_improve=3000, neigh=insert
# [297/576] n_starts=5000, max_iter=1000, stop_no_improve=3000, neigh=two_opt
# [298/576] n_starts=5000, max_iter=1000, stop_no_improve=10000, neigh=swap
# [299/576] n_starts=5000, max_iter=1000, stop_no_improve=10000, neigh=insert
# [300/576] n_starts=5000, max_iter=1000, stop_no_improve=10000, neigh=two_opt
# [301/576] n_starts=5000, max_iter=5000, stop_no_improve=500, neigh=swap
# [302/576] n_starts=5000, max_iter=5000, stop_no_improve=500, neigh=insert
# [303/576] n_starts=5000, max_iter=5000, stop_no_improve=500, neigh=two_opt
# [304/576] n_starts=5000, max_iter=5000, stop_no_improve=1000, neigh=swap
# [305/576] n_starts=5000, max_iter=5000, stop_no_improve=1000, neigh=insert
# [306/576] n_starts=5000, max_iter=5000, stop_no_improve=1000, neigh=two_opt
# [307/576] n_starts=5000, max_iter=5000, stop_no_improve=3000, neigh=swap
# [308/576] n_starts=5000, max_iter=5000, stop_no_improve=3000, neigh=insert
# [309/576] n_starts=5000, max_iter=5000, stop_no_improve=3000, neigh=two_opt
# [310/576] n_starts=5000, max_iter=5000, stop_no_improve=10000, neigh=swap
# [311/576] n_starts=5000, max_iter=5000, stop_no_improve=10000, neigh=insert
# [312/576] n_starts=5000, max_iter=5000, stop_no_improve=10000, neigh=two_opt
# [313/576] n_starts=5000, max_iter=50000, stop_no_improve=500, neigh=swap
# [314/576] n_starts=5000, max_iter=50000, stop_no_improve=500, neigh=insert
# [315/576] n_starts=5000, max_iter=50000, stop_no_improve=500, neigh=two_opt
# [316/576] n_starts=5000, max_iter=50000, stop_no_improve=1000, neigh=swap
# [317/576] n_starts=5000, max_iter=50000, stop_no_improve=1000, neigh=insert
# [318/576] n_starts=5000, max_iter=50000, stop_no_improve=1000, neigh=two_opt
# [319/576] n_starts=5000, max_iter=50000, stop_no_improve=3000, neigh=swap
# [320/576] n_starts=5000, max_iter=50000, stop_no_improve=3000, neigh=insert
# [321/576] n_starts=5000, max_iter=50000, stop_no_improve=3000, neigh=two_opt
# [322/576] n_starts=5000, max_iter=50000, stop_no_improve=10000, neigh=swap
# [323/576] n_starts=5000, max_iter=50000, stop_no_improve=10000, neigh=insert
# [324/576] n_starts=5000, max_iter=50000, stop_no_improve=10000, neigh=two_opt
# [325/576] n_starts=5000, max_iter=200000, stop_no_improve=500, neigh=swap
# [326/576] n_starts=5000, max_iter=200000, stop_no_improve=500, neigh=insert
# [327/576] n_starts=5000, max_iter=200000, stop_no_improve=500, neigh=two_opt
# [328/576] n_starts=5000, max_iter=200000, stop_no_improve=1000, neigh=swap
# [329/576] n_starts=5000, max_iter=200000, stop_no_improve=1000, neigh=insert
# [330/576] n_starts=5000, max_iter=200000, stop_no_improve=1000, neigh=two_opt
# [331/576] n_starts=5000, max_iter=200000, stop_no_improve=3000, neigh=swap
# [332/576] n_starts=5000, max_iter=200000, stop_no_improve=3000, neigh=insert
# [333/576] n_starts=5000, max_iter=200000, stop_no_improve=3000, neigh=two_opt
# [334/576] n_starts=5000, max_iter=200000, stop_no_improve=10000, neigh=swap
# [335/576] n_starts=5000, max_iter=200000, stop_no_improve=10000, neigh=insert
# [336/576] n_starts=5000, max_iter=200000, stop_no_improve=10000, neigh=two_opt
# [337/576] n_starts=10000, max_iter=1000, stop_no_improve=500, neigh=swap
# [338/576] n_starts=10000, max_iter=1000, stop_no_improve=500, neigh=insert
# [339/576] n_starts=10000, max_iter=1000, stop_no_improve=500, neigh=two_opt
# [340/576] n_starts=10000, max_iter=1000, stop_no_improve=1000, neigh=swap
# [341/576] n_starts=10000, max_iter=1000, stop_no_improve=1000, neigh=insert
# [342/576] n_starts=10000, max_iter=1000, stop_no_improve=1000, neigh=two_opt
# [343/576] n_starts=10000, max_iter=1000, stop_no_improve=3000, neigh=swap
# [344/576] n_starts=10000, max_iter=1000, stop_no_improve=3000, neigh=insert
# [345/576] n_starts=10000, max_iter=1000, stop_no_improve=3000, neigh=two_opt
# [346/576] n_starts=10000, max_iter=1000, stop_no_improve=10000, neigh=swap
# [347/576] n_starts=10000, max_iter=1000, stop_no_improve=10000, neigh=insert
# [348/576] n_starts=10000, max_iter=1000, stop_no_improve=10000, neigh=two_opt
# [349/576] n_starts=10000, max_iter=5000, stop_no_improve=500, neigh=swap
# [350/576] n_starts=10000, max_iter=5000, stop_no_improve=500, neigh=insert
# [351/576] n_starts=10000, max_iter=5000, stop_no_improve=500, neigh=two_opt
# [352/576] n_starts=10000, max_iter=5000, stop_no_improve=1000, neigh=swap
# [353/576] n_starts=10000, max_iter=5000, stop_no_improve=1000, neigh=insert
# [354/576] n_starts=10000, max_iter=5000, stop_no_improve=1000, neigh=two_opt
# [355/576] n_starts=10000, max_iter=5000, stop_no_improve=3000, neigh=swap
# [356/576] n_starts=10000, max_iter=5000, stop_no_improve=3000, neigh=insert
# [357/576] n_starts=10000, max_iter=5000, stop_no_improve=3000, neigh=two_opt
# [358/576] n_starts=10000, max_iter=5000, stop_no_improve=10000, neigh=swap
# [359/576] n_starts=10000, max_iter=5000, stop_no_improve=10000, neigh=insert
# [360/576] n_starts=10000, max_iter=5000, stop_no_improve=10000, neigh=two_opt
# [361/576] n_starts=10000, max_iter=50000, stop_no_improve=500, neigh=swap
# [362/576] n_starts=10000, max_iter=50000, stop_no_improve=500, neigh=insert
# [363/576] n_starts=10000, max_iter=50000, stop_no_improve=500, neigh=two_opt
# [364/576] n_starts=10000, max_iter=50000, stop_no_improve=1000, neigh=swap
# [365/576] n_starts=10000, max_iter=50000, stop_no_improve=1000, neigh=insert
# [366/576] n_starts=10000, max_iter=50000, stop_no_improve=1000, neigh=two_opt
# [367/576] n_starts=10000, max_iter=50000, stop_no_improve=3000, neigh=swap
# [368/576] n_starts=10000, max_iter=50000, stop_no_improve=3000, neigh=insert
# [369/576] n_starts=10000, max_iter=50000, stop_no_improve=3000, neigh=two_opt
# [370/576] n_starts=10000, max_iter=50000, stop_no_improve=10000, neigh=swap
# [371/576] n_starts=10000, max_iter=50000, stop_no_improve=10000, neigh=insert
# [372/576] n_starts=10000, max_iter=50000, stop_no_improve=10000, neigh=two_opt
# [373/576] n_starts=10000, max_iter=200000, stop_no_improve=500, neigh=swap
# [374/576] n_starts=10000, max_iter=200000, stop_no_improve=500, neigh=insert
# [375/576] n_starts=10000, max_iter=200000, stop_no_improve=500, neigh=two_opt
# [376/576] n_starts=10000, max_iter=200000, stop_no_improve=1000, neigh=swap
# [377/576] n_starts=10000, max_iter=200000, stop_no_improve=1000, neigh=insert
# [378/576] n_starts=10000, max_iter=200000, stop_no_improve=1000, neigh=two_opt
# [379/576] n_starts=10000, max_iter=200000, stop_no_improve=3000, neigh=swap
# [380/576] n_starts=10000, max_iter=200000, stop_no_improve=3000, neigh=insert
# [381/576] n_starts=10000, max_iter=200000, stop_no_improve=3000, neigh=two_opt
# [382/576] n_starts=10000, max_iter=200000, stop_no_improve=10000, neigh=swap
# [383/576] n_starts=10000, max_iter=200000, stop_no_improve=10000, neigh=insert
# [384/576] n_starts=10000, max_iter=200000, stop_no_improve=10000, neigh=two_opt
#
# Instancja: Dane_TSP_127.xlsx
# [385/576] n_starts=500, max_iter=1000, stop_no_improve=500, neigh=swap
# [386/576] n_starts=500, max_iter=1000, stop_no_improve=500, neigh=insert
# [387/576] n_starts=500, max_iter=1000, stop_no_improve=500, neigh=two_opt
# [388/576] n_starts=500, max_iter=1000, stop_no_improve=1000, neigh=swap
# [389/576] n_starts=500, max_iter=1000, stop_no_improve=1000, neigh=insert
# [390/576] n_starts=500, max_iter=1000, stop_no_improve=1000, neigh=two_opt
# [391/576] n_starts=500, max_iter=1000, stop_no_improve=3000, neigh=swap
# [392/576] n_starts=500, max_iter=1000, stop_no_improve=3000, neigh=insert
# [393/576] n_starts=500, max_iter=1000, stop_no_improve=3000, neigh=two_opt
# [394/576] n_starts=500, max_iter=1000, stop_no_improve=10000, neigh=swap
# [395/576] n_starts=500, max_iter=1000, stop_no_improve=10000, neigh=insert
# [396/576] n_starts=500, max_iter=1000, stop_no_improve=10000, neigh=two_opt
# [397/576] n_starts=500, max_iter=5000, stop_no_improve=500, neigh=swap
# [398/576] n_starts=500, max_iter=5000, stop_no_improve=500, neigh=insert
# [399/576] n_starts=500, max_iter=5000, stop_no_improve=500, neigh=two_opt
# [400/576] n_starts=500, max_iter=5000, stop_no_improve=1000, neigh=swap
# [401/576] n_starts=500, max_iter=5000, stop_no_improve=1000, neigh=insert
# [402/576] n_starts=500, max_iter=5000, stop_no_improve=1000, neigh=two_opt
# [403/576] n_starts=500, max_iter=5000, stop_no_improve=3000, neigh=swap
# [404/576] n_starts=500, max_iter=5000, stop_no_improve=3000, neigh=insert
# [405/576] n_starts=500, max_iter=5000, stop_no_improve=3000, neigh=two_opt
# [406/576] n_starts=500, max_iter=5000, stop_no_improve=10000, neigh=swap
# [407/576] n_starts=500, max_iter=5000, stop_no_improve=10000, neigh=insert
# [408/576] n_starts=500, max_iter=5000, stop_no_improve=10000, neigh=two_opt
# [409/576] n_starts=500, max_iter=50000, stop_no_improve=500, neigh=swap
# [410/576] n_starts=500, max_iter=50000, stop_no_improve=500, neigh=insert
# [411/576] n_starts=500, max_iter=50000, stop_no_improve=500, neigh=two_opt
# [412/576] n_starts=500, max_iter=50000, stop_no_improve=1000, neigh=swap
# [413/576] n_starts=500, max_iter=50000, stop_no_improve=1000, neigh=insert
# [414/576] n_starts=500, max_iter=50000, stop_no_improve=1000, neigh=two_opt
# [415/576] n_starts=500, max_iter=50000, stop_no_improve=3000, neigh=swap
# [416/576] n_starts=500, max_iter=50000, stop_no_improve=3000, neigh=insert
# [417/576] n_starts=500, max_iter=50000, stop_no_improve=3000, neigh=two_opt
# [418/576] n_starts=500, max_iter=50000, stop_no_improve=10000, neigh=swap
# [419/576] n_starts=500, max_iter=50000, stop_no_improve=10000, neigh=insert
# [420/576] n_starts=500, max_iter=50000, stop_no_improve=10000, neigh=two_opt
# [421/576] n_starts=500, max_iter=200000, stop_no_improve=500, neigh=swap
# [422/576] n_starts=500, max_iter=200000, stop_no_improve=500, neigh=insert
# [423/576] n_starts=500, max_iter=200000, stop_no_improve=500, neigh=two_opt
# [424/576] n_starts=500, max_iter=200000, stop_no_improve=1000, neigh=swap
# [425/576] n_starts=500, max_iter=200000, stop_no_improve=1000, neigh=insert
# [426/576] n_starts=500, max_iter=200000, stop_no_improve=1000, neigh=two_opt
# [427/576] n_starts=500, max_iter=200000, stop_no_improve=3000, neigh=swap
# [428/576] n_starts=500, max_iter=200000, stop_no_improve=3000, neigh=insert
# [429/576] n_starts=500, max_iter=200000, stop_no_improve=3000, neigh=two_opt
# [430/576] n_starts=500, max_iter=200000, stop_no_improve=10000, neigh=swap
# [431/576] n_starts=500, max_iter=200000, stop_no_improve=10000, neigh=insert
# [432/576] n_starts=500, max_iter=200000, stop_no_improve=10000, neigh=two_opt
# [433/576] n_starts=1000, max_iter=1000, stop_no_improve=500, neigh=swap
# [434/576] n_starts=1000, max_iter=1000, stop_no_improve=500, neigh=insert
# [435/576] n_starts=1000, max_iter=1000, stop_no_improve=500, neigh=two_opt
# [436/576] n_starts=1000, max_iter=1000, stop_no_improve=1000, neigh=swap
# [437/576] n_starts=1000, max_iter=1000, stop_no_improve=1000, neigh=insert
# [438/576] n_starts=1000, max_iter=1000, stop_no_improve=1000, neigh=two_opt
# [439/576] n_starts=1000, max_iter=1000, stop_no_improve=3000, neigh=swap
# [440/576] n_starts=1000, max_iter=1000, stop_no_improve=3000, neigh=insert
# [441/576] n_starts=1000, max_iter=1000, stop_no_improve=3000, neigh=two_opt
# [442/576] n_starts=1000, max_iter=1000, stop_no_improve=10000, neigh=swap
# [443/576] n_starts=1000, max_iter=1000, stop_no_improve=10000, neigh=insert
# [444/576] n_starts=1000, max_iter=1000, stop_no_improve=10000, neigh=two_opt
# [445/576] n_starts=1000, max_iter=5000, stop_no_improve=500, neigh=swap
# [446/576] n_starts=1000, max_iter=5000, stop_no_improve=500, neigh=insert
# [447/576] n_starts=1000, max_iter=5000, stop_no_improve=500, neigh=two_opt
# [448/576] n_starts=1000, max_iter=5000, stop_no_improve=1000, neigh=swap
# [449/576] n_starts=1000, max_iter=5000, stop_no_improve=1000, neigh=insert
# [450/576] n_starts=1000, max_iter=5000, stop_no_improve=1000, neigh=two_opt
# [451/576] n_starts=1000, max_iter=5000, stop_no_improve=3000, neigh=swap
# [452/576] n_starts=1000, max_iter=5000, stop_no_improve=3000, neigh=insert
# [453/576] n_starts=1000, max_iter=5000, stop_no_improve=3000, neigh=two_opt
# [454/576] n_starts=1000, max_iter=5000, stop_no_improve=10000, neigh=swap
# [455/576] n_starts=1000, max_iter=5000, stop_no_improve=10000, neigh=insert
# [456/576] n_starts=1000, max_iter=5000, stop_no_improve=10000, neigh=two_opt
# [457/576] n_starts=1000, max_iter=50000, stop_no_improve=500, neigh=swap
# [458/576] n_starts=1000, max_iter=50000, stop_no_improve=500, neigh=insert
# [459/576] n_starts=1000, max_iter=50000, stop_no_improve=500, neigh=two_opt
# [460/576] n_starts=1000, max_iter=50000, stop_no_improve=1000, neigh=swap
# [461/576] n_starts=1000, max_iter=50000, stop_no_improve=1000, neigh=insert
# [462/576] n_starts=1000, max_iter=50000, stop_no_improve=1000, neigh=two_opt
# [463/576] n_starts=1000, max_iter=50000, stop_no_improve=3000, neigh=swap
# [464/576] n_starts=1000, max_iter=50000, stop_no_improve=3000, neigh=insert
# [465/576] n_starts=1000, max_iter=50000, stop_no_improve=3000, neigh=two_opt
# [466/576] n_starts=1000, max_iter=50000, stop_no_improve=10000, neigh=swap
# [467/576] n_starts=1000, max_iter=50000, stop_no_improve=10000, neigh=insert
# [468/576] n_starts=1000, max_iter=50000, stop_no_improve=10000, neigh=two_opt
# [469/576] n_starts=1000, max_iter=200000, stop_no_improve=500, neigh=swap
# [470/576] n_starts=1000, max_iter=200000, stop_no_improve=500, neigh=insert
# [471/576] n_starts=1000, max_iter=200000, stop_no_improve=500, neigh=two_opt
# [472/576] n_starts=1000, max_iter=200000, stop_no_improve=1000, neigh=swap
# [473/576] n_starts=1000, max_iter=200000, stop_no_improve=1000, neigh=insert
# [474/576] n_starts=1000, max_iter=200000, stop_no_improve=1000, neigh=two_opt
# [475/576] n_starts=1000, max_iter=200000, stop_no_improve=3000, neigh=swap
# [476/576] n_starts=1000, max_iter=200000, stop_no_improve=3000, neigh=insert
# [477/576] n_starts=1000, max_iter=200000, stop_no_improve=3000, neigh=two_opt
# [478/576] n_starts=1000, max_iter=200000, stop_no_improve=10000, neigh=swap
# [479/576] n_starts=1000, max_iter=200000, stop_no_improve=10000, neigh=insert
# [480/576] n_starts=1000, max_iter=200000, stop_no_improve=10000, neigh=two_opt
# [481/576] n_starts=5000, max_iter=1000, stop_no_improve=500, neigh=swap
# [482/576] n_starts=5000, max_iter=1000, stop_no_improve=500, neigh=insert
# [483/576] n_starts=5000, max_iter=1000, stop_no_improve=500, neigh=two_opt
# [484/576] n_starts=5000, max_iter=1000, stop_no_improve=1000, neigh=swap
# [485/576] n_starts=5000, max_iter=1000, stop_no_improve=1000, neigh=insert
# [486/576] n_starts=5000, max_iter=1000, stop_no_improve=1000, neigh=two_opt
# [487/576] n_starts=5000, max_iter=1000, stop_no_improve=3000, neigh=swap
# [488/576] n_starts=5000, max_iter=1000, stop_no_improve=3000, neigh=insert
# [489/576] n_starts=5000, max_iter=1000, stop_no_improve=3000, neigh=two_opt
# [490/576] n_starts=5000, max_iter=1000, stop_no_improve=10000, neigh=swap
# [491/576] n_starts=5000, max_iter=1000, stop_no_improve=10000, neigh=insert
# [492/576] n_starts=5000, max_iter=1000, stop_no_improve=10000, neigh=two_opt
# [493/576] n_starts=5000, max_iter=5000, stop_no_improve=500, neigh=swap
# [494/576] n_starts=5000, max_iter=5000, stop_no_improve=500, neigh=insert
# [495/576] n_starts=5000, max_iter=5000, stop_no_improve=500, neigh=two_opt
# [496/576] n_starts=5000, max_iter=5000, stop_no_improve=1000, neigh=swap
# [497/576] n_starts=5000, max_iter=5000, stop_no_improve=1000, neigh=insert
# [498/576] n_starts=5000, max_iter=5000, stop_no_improve=1000, neigh=two_opt
# [499/576] n_starts=5000, max_iter=5000, stop_no_improve=3000, neigh=swap
# [500/576] n_starts=5000, max_iter=5000, stop_no_improve=3000, neigh=insert
# [501/576] n_starts=5000, max_iter=5000, stop_no_improve=3000, neigh=two_opt
# [502/576] n_starts=5000, max_iter=5000, stop_no_improve=10000, neigh=swap
# [503/576] n_starts=5000, max_iter=5000, stop_no_improve=10000, neigh=insert
# [504/576] n_starts=5000, max_iter=5000, stop_no_improve=10000, neigh=two_opt
# [505/576] n_starts=5000, max_iter=50000, stop_no_improve=500, neigh=swap
# [506/576] n_starts=5000, max_iter=50000, stop_no_improve=500, neigh=insert
# [507/576] n_starts=5000, max_iter=50000, stop_no_improve=500, neigh=two_opt
# [508/576] n_starts=5000, max_iter=50000, stop_no_improve=1000, neigh=swap
# [509/576] n_starts=5000, max_iter=50000, stop_no_improve=1000, neigh=insert
# [510/576] n_starts=5000, max_iter=50000, stop_no_improve=1000, neigh=two_opt
# [511/576] n_starts=5000, max_iter=50000, stop_no_improve=3000, neigh=swap
# [512/576] n_starts=5000, max_iter=50000, stop_no_improve=3000, neigh=insert
# [513/576] n_starts=5000, max_iter=50000, stop_no_improve=3000, neigh=two_opt
# [514/576] n_starts=5000, max_iter=50000, stop_no_improve=10000, neigh=swap
# [515/576] n_starts=5000, max_iter=50000, stop_no_improve=10000, neigh=insert
# [516/576] n_starts=5000, max_iter=50000, stop_no_improve=10000, neigh=two_opt
# [517/576] n_starts=5000, max_iter=200000, stop_no_improve=500, neigh=swap
# [518/576] n_starts=5000, max_iter=200000, stop_no_improve=500, neigh=insert
# [519/576] n_starts=5000, max_iter=200000, stop_no_improve=500, neigh=two_opt
# [520/576] n_starts=5000, max_iter=200000, stop_no_improve=1000, neigh=swap
# [521/576] n_starts=5000, max_iter=200000, stop_no_improve=1000, neigh=insert
# [522/576] n_starts=5000, max_iter=200000, stop_no_improve=1000, neigh=two_opt
# [523/576] n_starts=5000, max_iter=200000, stop_no_improve=3000, neigh=swap
# [524/576] n_starts=5000, max_iter=200000, stop_no_improve=3000, neigh=insert
# [525/576] n_starts=5000, max_iter=200000, stop_no_improve=3000, neigh=two_opt
# [526/576] n_starts=5000, max_iter=200000, stop_no_improve=10000, neigh=swap
# [527/576] n_starts=5000, max_iter=200000, stop_no_improve=10000, neigh=insert
# [528/576] n_starts=5000, max_iter=200000, stop_no_improve=10000, neigh=two_opt
# [529/576] n_starts=10000, max_iter=1000, stop_no_improve=500, neigh=swap
# [530/576] n_starts=10000, max_iter=1000, stop_no_improve=500, neigh=insert
# [531/576] n_starts=10000, max_iter=1000, stop_no_improve=500, neigh=two_opt
# [532/576] n_starts=10000, max_iter=1000, stop_no_improve=1000, neigh=swap
# [533/576] n_starts=10000, max_iter=1000, stop_no_improve=1000, neigh=insert
# [534/576] n_starts=10000, max_iter=1000, stop_no_improve=1000, neigh=two_opt
# [535/576] n_starts=10000, max_iter=1000, stop_no_improve=3000, neigh=swap
# [536/576] n_starts=10000, max_iter=1000, stop_no_improve=3000, neigh=insert
# [537/576] n_starts=10000, max_iter=1000, stop_no_improve=3000, neigh=two_opt
# [538/576] n_starts=10000, max_iter=1000, stop_no_improve=10000, neigh=swap
# [539/576] n_starts=10000, max_iter=1000, stop_no_improve=10000, neigh=insert
# [540/576] n_starts=10000, max_iter=1000, stop_no_improve=10000, neigh=two_opt
# [541/576] n_starts=10000, max_iter=5000, stop_no_improve=500, neigh=swap
# [542/576] n_starts=10000, max_iter=5000, stop_no_improve=500, neigh=insert
# [543/576] n_starts=10000, max_iter=5000, stop_no_improve=500, neigh=two_opt
# [544/576] n_starts=10000, max_iter=5000, stop_no_improve=1000, neigh=swap
# [545/576] n_starts=10000, max_iter=5000, stop_no_improve=1000, neigh=insert
# [546/576] n_starts=10000, max_iter=5000, stop_no_improve=1000, neigh=two_opt
# [547/576] n_starts=10000, max_iter=5000, stop_no_improve=3000, neigh=swap
# [548/576] n_starts=10000, max_iter=5000, stop_no_improve=3000, neigh=insert
# [549/576] n_starts=10000, max_iter=5000, stop_no_improve=3000, neigh=two_opt
# [550/576] n_starts=10000, max_iter=5000, stop_no_improve=10000, neigh=swap
# [551/576] n_starts=10000, max_iter=5000, stop_no_improve=10000, neigh=insert
# [552/576] n_starts=10000, max_iter=5000, stop_no_improve=10000, neigh=two_opt
# [553/576] n_starts=10000, max_iter=50000, stop_no_improve=500, neigh=swap
# [554/576] n_starts=10000, max_iter=50000, stop_no_improve=500, neigh=insert
# [555/576] n_starts=10000, max_iter=50000, stop_no_improve=500, neigh=two_opt
# [556/576] n_starts=10000, max_iter=50000, stop_no_improve=1000, neigh=swap
# [557/576] n_starts=10000, max_iter=50000, stop_no_improve=1000, neigh=insert
# [558/576] n_starts=10000, max_iter=50000, stop_no_improve=1000, neigh=two_opt
# [559/576] n_starts=10000, max_iter=50000, stop_no_improve=3000, neigh=swap
# [560/576] n_starts=10000, max_iter=50000, stop_no_improve=3000, neigh=insert
# [561/576] n_starts=10000, max_iter=50000, stop_no_improve=3000, neigh=two_opt
# [562/576] n_starts=10000, max_iter=50000, stop_no_improve=10000, neigh=swap
# [563/576] n_starts=10000, max_iter=50000, stop_no_improve=10000, neigh=insert
# [564/576] n_starts=10000, max_iter=50000, stop_no_improve=10000, neigh=two_opt
# [565/576] n_starts=10000, max_iter=200000, stop_no_improve=500, neigh=swap
# [566/576] n_starts=10000, max_iter=200000, stop_no_improve=500, neigh=insert
# [567/576] n_starts=10000, max_iter=200000, stop_no_improve=500, neigh=two_opt
# [568/576] n_starts=10000, max_iter=200000, stop_no_improve=1000, neigh=swap
# [569/576] n_starts=10000, max_iter=200000, stop_no_improve=1000, neigh=insert
# [570/576] n_starts=10000, max_iter=200000, stop_no_improve=1000, neigh=two_opt
# [571/576] n_starts=10000, max_iter=200000, stop_no_improve=3000, neigh=swap
# [572/576] n_starts=10000, max_iter=200000, stop_no_improve=3000, neigh=insert
# [573/576] n_starts=10000, max_iter=200000, stop_no_improve=3000, neigh=two_opt
# [574/576] n_starts=10000, max_iter=200000, stop_no_improve=10000, neigh=swap
# [575/576] n_starts=10000, max_iter=200000, stop_no_improve=10000, neigh=insert
# [576/576] n_starts=10000, max_iter=200000, stop_no_improve=10000, neigh=two_opt
#
# Łączny czas eksperymentów: 143.31 min (8598.41 sek)
#
# Podsumowanie (pierwsze 20 wierszy):
#         instance  n_starts  max_iter  stop_no_improve neighborhood_type  mean_cost  mean_runtime  min_cost                                                                                                                                min_route
# Dane_TSP_48.xlsx       500    200000             3000           two_opt     9858.0      1.743128    9809.0 40-9-1-8-38-31-44-18-7-36-28-30-6-37-19-27-43-17-0-4-26-35-45-10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15
# Dane_TSP_48.xlsx      5000     50000             3000           two_opt     9811.0     12.809725    9809.0 3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35-26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23
# Dane_TSP_48.xlsx     10000    200000            10000           two_opt     9813.0     45.894092    9809.0 7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35-26-4-0-17-43-27-19-37-6-30-28-36
# Dane_TSP_48.xlsx      5000    200000            10000           two_opt     9814.0     24.414855    9809.0 45-10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30-6-37-19-27-43-17-0-4-26-35
# Dane_TSP_48.xlsx      1000    200000              500           two_opt     9960.6      1.434257    9809.0 14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30-6-37-19-27-43-17-0-4-26-35-45-10-24-42-2-29-5-48-39-32-21-47-13-25
# Dane_TSP_48.xlsx      5000     50000            10000           two_opt     9821.0     23.175109    9809.0 10-45-35-26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24
# Dane_TSP_48.xlsx     10000     50000             1000            insert     9953.8     22.820672    9809.0 18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35-26-4-0-17-43-27-19-37-6-30-28-36-7
# Dane_TSP_48.xlsx     10000     50000             1000           two_opt     9825.8     14.964899    9809.0 0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35-26-4
# Dane_TSP_48.xlsx      5000     50000            10000            insert     9883.0     35.579436    9809.0 15-40-9-1-8-38-31-44-18-7-36-28-30-6-37-19-27-43-17-0-4-26-35-45-10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46
# Dane_TSP_48.xlsx     10000     50000             3000           two_opt     9811.0     24.887717    9809.0 6-37-19-27-43-17-0-4-26-35-45-10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28-30
# Dane_TSP_48.xlsx     10000     50000            10000           two_opt     9813.0     44.848008    9809.0 34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35-26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41
# Dane_TSP_48.xlsx     10000    200000              500           two_opt     9865.2     10.157909    9809.0 34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35-26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41
# Dane_TSP_48.xlsx      1000     50000             3000           two_opt     9841.8      5.669460    9809.0 26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35
# Dane_TSP_48.xlsx       500     50000            10000           two_opt     9854.2      2.674727    9809.0 15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35-26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40
# Dane_TSP_48.xlsx     10000    200000             3000           two_opt     9815.8     26.073432    9809.0 30-6-37-19-27-43-17-0-4-26-35-45-10-24-42-2-29-5-48-39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-9-1-8-38-31-44-18-7-36-28
# Dane_TSP_48.xlsx     10000     50000             3000            insert     9879.8     42.401030    9809.0 25-13-47-21-32-39-48-5-29-2-42-24-10-45-35-26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23-3-22-16-41-34-14
# Dane_TSP_48.xlsx      1000     50000            10000           two_opt     9843.2      4.970485    9819.0 39-32-21-47-13-25-14-34-41-16-22-3-23-11-12-20-33-46-15-40-1-8-9-38-31-44-18-7-36-28-30-6-37-19-27-43-17-0-4-26-35-45-10-24-42-2-29-5-48
# Dane_TSP_48.xlsx      1000    200000             1000           two_opt     9880.0      2.683938    9819.0 3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35-26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-9-8-1-40-15-46-33-20-12-11-23
# Dane_TSP_48.xlsx      5000      5000             1000           two_opt     9840.0      7.054643    9819.0 35-26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-9-8-1-40-15-46-33-20-12-11-23-3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45
# Dane_TSP_48.xlsx      5000      5000             3000           two_opt     9859.6      7.437740    9819.0 14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35-26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-9-8-1-40-15-46-33-20-12-11-23-3-22-16-41-34
#
# Najlepsze parametry dla każdej instancji:
#
# Dane_TSP_48.xlsx
# odległość 9809.0 = {'instance': 'Dane_TSP_48.xlsx', 'n_starts': 5000, 'max_iter': 50000, 'stop_no_improve': 3000, 'neighborhood_type': 'two_opt', 'mean_cost': 9811.0, 'mean_runtime': 12.809725379943847, 'min_cost': 9809.0, 'min_route': '3-22-16-41-34-14-25-13-47-21-32-39-48-5-29-2-42-24-10-45-35-26-4-0-17-43-27-19-37-6-30-28-36-7-18-44-31-38-8-1-9-40-15-46-33-20-12-11-23'}
#
# Dane_TSP_76.xlsx
# odległość 97734.075 = {'instance': 'Dane_TSP_76.xlsx', 'n_starts': 10000, 'max_iter': 50000, 'stop_no_improve': 3000, 'neighborhood_type': 'two_opt', 'mean_cost': 97834.326, 'mean_runtime': 54.612512826919556, 'min_cost': 97734.075, 'min_route': '24-25-21-22-23-1-76-75-2-3-4-6-7-8-9-10-5-20-19-31-30-29-26-27-28-43-42-54-53-52-49-50-51-66-65-71-72-73-64-63-57-56-55-58-62-61-59-60-41-40-39-38-34-33-32-35-36-37-18-17-11-12-16-15-13-14-74-0-70-67-68-69-47-48-44-45-46'}
#
# Dane_TSP_127.xlsx
# odległość 111148.091 = {'instance': 'Dane_TSP_127.xlsx', 'n_starts': 10000, 'max_iter': 200000, 'stop_no_improve': 10000, 'neighborhood_type': 'two_opt', 'mean_cost': 111548.948, 'mean_runtime': 129.40546016693116, 'min_cost': 111148.091, 'min_route': '13-50-115-10-100-64-58-91-61-62-59-60-116-90-3-11-9-24-23-4-22-19-72-8-67-73-74-68-71-70-69-75-76-78-117-84-81-126-82-83-101-102-63-119-96-109-88-87-86-85-110-104-125-89-92-99-65-113-66-55-47-49-53-48-118-46-94-112-111-107-0-98-127-93-95-123-97-28-122-33-32-29-25-26-38-39-42-34-30-43-40-44-103-45-54-57-56-124-52-5-121-51-2-35-37-36-41-14-12-31-27-80-79-77-18-21-17-20-108-15-106-6-114-105-16-1-7-120'}
