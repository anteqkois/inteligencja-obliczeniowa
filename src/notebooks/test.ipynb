# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np, time
from src.utils.distance import route_length_np, route_length_fast

# pokazywanie wszystkich kolumn i wierszy
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
np.set_printoptions(threshold=np.inf)

D = np.random.rand(1000, 1000)
route = np.random.permutation(1000)

t1 = time.time(); route_length_np(D, route); print("NumPy:", time.time()-t1)
t2 = time.time(); route_length_fast(D, route); print("Numba:", time.time()-t2)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# NumPy: 0.00023984909057617188
# Numba: 4.410743713378906e-05
